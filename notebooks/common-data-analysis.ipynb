# %% [markdown]
# # Exploratory Data Analysis for NBA Lineup Prediction and Hidden Patterns
#
# This notebook organizes the data exploration steps from the raw CSV file and implements several views to uncover hidden patterns. Our goals include:
#
# - **Lineup stability and variation** over time
# - **Frequency of player appearances** in different positions (e.g., home_0 to home_4)
# - **Outcome analysis** by lineup
# - **Common matchups:** identifying which home players appear most frequently against specific away lineups
#
# These insights will help us engineer better features for the predictive model.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import glob
import os

import matplotlib.pyplot as plt
import seaborn as sns

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')

# Set display options for Pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## 1. Load and Inspect the Raw Data
#
# In this section, we load the raw CSV file for the 2007 season and inspect its contents.

# %%
# Load the 2007 dataset (update the path as needed)

data_path = "../data/matchups-2007.csv"
df2007 = pd.read_csv(data_path)

# Display the first few rows and information about the dataset
print(df2007.head())
print(df2007.info())
# Out:
#            game  season home_team away_team  starting_min  end_min  \
# 0  200610310LAL    2007       LAL       PHO             0        5
# 1  200610310LAL    2007       LAL       PHO             6        7
# 2  200610310LAL    2007       LAL       PHO             8        9
# 3  200610310LAL    2007       LAL       PHO            10       10
# 4  200610310LAL    2007       LAL       PHO            11       11
#
#          home_0         home_1         home_2         home_3  \
# 0  Andrew Bynum     Lamar Odom    Luke Walton  Sasha Vujacic
# 1  Andrew Bynum     Lamar Odom    Luke Walton  Sasha Vujacic
# 2    Lamar Odom    Luke Walton  Maurice Evans   Ronny Turiaf
# 3    Lamar Odom    Luke Walton  Maurice Evans   Ronny Turiaf
# 4   Luke Walton  Maurice Evans   Ronny Turiaf   Smush Parker
#
#                 home_4             away_0           away_1       away_2  \
# 0         Smush Parker         Boris Diaw      Kurt Thomas    Raja Bell
# 1         Smush Parker  Amar'e Stoudemire  Leandro Barbosa    Raja Bell
# 2         Smush Parker  Amar'e Stoudemire  Leandro Barbosa    Raja Bell
# 3         Smush Parker         Boris Diaw      James Jones  Kurt Thomas
# 4  Vladimir Radmanovic         Boris Diaw      James Jones  Kurt Thomas
#
#             away_3        away_4  fga_home  fta_home  fgm_home  fga_2_home  \
# 0     Shawn Marion    Steve Nash        10         4         4           7
# 1     Shawn Marion    Steve Nash         3         0         2           2
# 2     Shawn Marion    Steve Nash         4         0         2           4
# 3  Leandro Barbosa  Marcus Banks         2         0         2           2
# 4  Leandro Barbosa  Marcus Banks         2         0         1           2
#
#    fgm_2_home  fga_3_home  fgm_3_home  ast_home  blk_home  pf_home  reb_home  \
# 0           3           3           1         3         0        1         1
# 1           2           1           0         1         0        0         2
# 2           2           0           0         2         1        1         2
# 3           2           0           0         1         0        0         0
# 4           1           0           0         1         0        1         0
#
#    dreb_home  oreb_home  to_home  pts_home  pct_home  pct_2_home  pct_3_home  \
# 0          1          0        1         9  0.400000    0.428571    0.333333
# 1          2          0        2         4  0.666667    1.000000    0.000000
# 2          1          1        2         4  0.500000    0.500000    0.000000
# 3          0          0        0         4  1.000000    1.000000    0.000000
# 4          0          0        0         2  0.500000    0.500000    0.000000
#
#    fga_visitor  fta_visitor  fgm_visitor  fga_2_visitor  fgm_2_visitor  \
# 0           11            1           10              8              8
# 1            6            0            4              4              3
# 2            2            2            1              2              1
# 3            2            0            1              0              0
# 4            1            0            1              1              1
#
#    fga_3_visitor  fgm_3_visitor  ast_visitor  blk_visitor  pf_visitor  \
# 0              3              2            6            0           0
# 1              2              1            4            0           0
# 2              0              0            1            0           0
# 3              2              1            1            0           0
# 4              0              0            1            0           1
#
#    reb_visitor  dreb_visitor  oreb_visitor  to_visitor  pts_visitor  \
# 0            7             7             0           1           22
# 1            1             1             0           0            9
# 2            1             1             0           1            2
# 3            1             0             1           1            3
# 4            1             1             0           1            2
#
#    pct_visitor  pct_2_visitor  pct_3_visitor  outcome
# 0     0.909091           1.00       0.666667       -1
# 1     0.666667           0.75       0.500000       -1
# 2     0.500000           0.50       0.000000        1
# 3     0.500000           0.00       0.500000        1
# 4     1.000000           1.00       0.000000       -1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27500 entries, 0 to 27499
# Data columns (total 53 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   game           27500 non-null  object
#  1   season         27500 non-null  int64
#  2   home_team      27500 non-null  object
#  3   away_team      27500 non-null  object
#  4   starting_min   27500 non-null  int64
#  5   end_min        27500 non-null  int64
#  6   home_0         27500 non-null  object
#  7   home_1         27500 non-null  object
#  8   home_2         27500 non-null  object
#  9   home_3         27500 non-null  object
#  10  home_4         27500 non-null  object
#  11  away_0         27500 non-null  object
#  12  away_1         27500 non-null  object
#  13  away_2         27500 non-null  object
#  14  away_3         27500 non-null  object
#  15  away_4         27500 non-null  object
#  16  fga_home       27500 non-null  int64
#  17  fta_home       27500 non-null  int64
#  18  fgm_home       27500 non-null  int64
#  19  fga_2_home     27500 non-null  int64
#  20  fgm_2_home     27500 non-null  int64
#  21  fga_3_home     27500 non-null  int64
#  22  fgm_3_home     27500 non-null  int64
#  23  ast_home       27500 non-null  int64
#  24  blk_home       27500 non-null  int64
#  25  pf_home        27500 non-null  int64
#  26  reb_home       27500 non-null  int64
#  27  dreb_home      27500 non-null  int64
#  28  oreb_home      27500 non-null  int64
#  29  to_home        27500 non-null  int64
#  30  pts_home       27500 non-null  int64
#  31  pct_home       27500 non-null  float64
#  32  pct_2_home     27500 non-null  float64
#  33  pct_3_home     27500 non-null  float64
#  34  fga_visitor    27500 non-null  int64
#  35  fta_visitor    27500 non-null  int64
#  36  fgm_visitor    27500 non-null  int64
#  37  fga_2_visitor  27500 non-null  int64
#  38  fgm_2_visitor  27500 non-null  int64
#  39  fga_3_visitor  27500 non-null  int64
#  40  fgm_3_visitor  27500 non-null  int64
#  41  ast_visitor    27500 non-null  int64
#  42  blk_visitor    27500 non-null  int64
#  43  pf_visitor     27500 non-null  int64
#  44  reb_visitor    27500 non-null  int64
#  45  dreb_visitor   27500 non-null  int64
#  46  oreb_visitor   27500 non-null  int64
#  47  to_visitor     27500 non-null  int64
#  48  pts_visitor    27500 non-null  int64
#  49  pct_visitor    27500 non-null  float64
#  50  pct_2_visitor  27500 non-null  float64
#  51  pct_3_visitor  27500 non-null  float64
#  52  outcome        27500 non-null  int64
# dtypes: float64(6), int64(34), object(13)
# memory usage: 11.1+ MB
# None

# %% [markdown]
# ## 2. Filter Data and Create a Date Column
#
# We now filter the dataset to include only the allowed features and extract a proper date from the `game` column.

# %%
# Define the allowed features
allowed_features = [
    'game', 'season', 'home_team', 'away_team', 'starting_min',
    'home_0', 'home_1', 'home_2', 'home_3', 'home_4',
    'away_0', 'away_1', 'away_2', 'away_3', 'away_4',
    'outcome'
]

# Filter the dataframe and create a copy
df_filtered = df2007[allowed_features].copy()

# Create a date column from the first 8 characters of the 'game' column
df_filtered['date'] = pd.to_datetime(df_filtered['game'].str[:8], format='%Y%m%d')

print(df_filtered.head())
# Out:
#            game  season home_team away_team  starting_min        home_0  \
# 0  200610310LAL    2007       LAL       PHO             0  Andrew Bynum
# 1  200610310LAL    2007       LAL       PHO             6  Andrew Bynum
# 2  200610310LAL    2007       LAL       PHO             8    Lamar Odom
# 3  200610310LAL    2007       LAL       PHO            10    Lamar Odom
# 4  200610310LAL    2007       LAL       PHO            11   Luke Walton
#
#           home_1         home_2         home_3               home_4  \
# 0     Lamar Odom    Luke Walton  Sasha Vujacic         Smush Parker
# 1     Lamar Odom    Luke Walton  Sasha Vujacic         Smush Parker
# 2    Luke Walton  Maurice Evans   Ronny Turiaf         Smush Parker
# 3    Luke Walton  Maurice Evans   Ronny Turiaf         Smush Parker
# 4  Maurice Evans   Ronny Turiaf   Smush Parker  Vladimir Radmanovic
#
#               away_0           away_1       away_2           away_3  \
# 0         Boris Diaw      Kurt Thomas    Raja Bell     Shawn Marion
# 1  Amar'e Stoudemire  Leandro Barbosa    Raja Bell     Shawn Marion
# 2  Amar'e Stoudemire  Leandro Barbosa    Raja Bell     Shawn Marion
# 3         Boris Diaw      James Jones  Kurt Thomas  Leandro Barbosa
# 4         Boris Diaw      James Jones  Kurt Thomas  Leandro Barbosa
#
#          away_4  outcome       date
# 0    Steve Nash       -1 2006-10-31
# 1    Steve Nash       -1 2006-10-31
# 2    Steve Nash        1 2006-10-31
# 3  Marcus Banks        1 2006-10-31
# 4  Marcus Banks       -1 2006-10-31

# %% [markdown]
# ## 3. Create Lineup Tuples for Home and Away Teams
#
# To analyze lineup frequency and uniqueness, we create sorted tuples for both home and away lineups.

# %%
# Create lineup tuples (sorted alphabetically for consistency)
df_filtered['home_lineup'] = df_filtered[['home_0', 'home_1', 'home_2', 'home_3', 'home_4']].apply(lambda x: tuple(sorted(x)), axis=1)
df_filtered['away_lineup'] = df_filtered[['away_0', 'away_1', 'away_2', 'away_3', 'away_4']].apply(lambda x: tuple(sorted(x)), axis=1)

df_filtered[['game', 'home_lineup', 'away_lineup', 'date']].head()
# Out:
#            game                                        home_lineup  \
# 0  200610310LAL  (Andrew Bynum, Lamar Odom, Luke Walton, Sasha ...
# 1  200610310LAL  (Andrew Bynum, Lamar Odom, Luke Walton, Sasha ...
# 2  200610310LAL  (Lamar Odom, Luke Walton, Maurice Evans, Ronny...
# 3  200610310LAL  (Lamar Odom, Luke Walton, Maurice Evans, Ronny...
# 4  200610310LAL  (Luke Walton, Maurice Evans, Ronny Turiaf, Smu...
#
#                                          away_lineup       date
# 0  (Boris Diaw, Kurt Thomas, Raja Bell, Shawn Mar... 2006-10-31
# 1  (Amar'e Stoudemire, Leandro Barbosa, Raja Bell... 2006-10-31
# 2  (Amar'e Stoudemire, Leandro Barbosa, Raja Bell... 2006-10-31
# 3  (Boris Diaw, James Jones, Kurt Thomas, Leandro... 2006-10-31
# 4  (Boris Diaw, James Jones, Kurt Thomas, Leandro... 2006-10-31

# %% [markdown]
# ## 4. Unique Lineup Counts per Game
#
# Here we group by game and count how many unique home and away lineups were used.

# %%
# Count unique lineups per game
lineup_counts = df_filtered.groupby('game').agg(
    unique_home_lineups=('home_lineup', 'nunique'),
    unique_away_lineups=('away_lineup', 'nunique')
).reset_index()

lineup_counts.head()
# Out:
#            game  unique_home_lineups  unique_away_lineups
# 0  200610310LAL                   11                    9
# 1  200610310MIA                   11                   16
# 2  200611010BOS                   19                   17
# 3  200611010CHA                   16                   15
# 4  200611010CLE                   12                   10

# %% [markdown]
# ## 5. Most Frequently Used Lineups per Game
#
# We now identify the most frequently used home and away lineups for each game.

# %%
# Count occurrences of each lineup combination
lineup_usage = df_filtered.groupby(['game', 'home_team', 'away_team', 'date', 'home_lineup', 'away_lineup']).size().reset_index(name='count')

# For each game, select the lineup combination with the highest count
most_used_lineups = lineup_usage.sort_values(['game', 'count'], ascending=[True, False]).drop_duplicates('game')

print(most_used_lineups.head())
# Out:
#              game home_team away_team       date  \
# 2    200610310LAL       LAL       PHO 2006-10-31
# 36   200610310MIA       MIA       CHI 2006-10-31
# 59   200611010BOS       BOS       NOK 2006-11-01
# 72   200611010CHA       CHA       IND 2006-11-01
# 115  200611010CLE       CLE       WAS 2006-11-01
#
#                                            home_lineup  \
# 2    (Andrew Bynum, Lamar Odom, Luke Walton, Mauric...
# 36   (Antoine Walker, Dwyane Wade, Gary Payton, Sha...
# 59   (Delonte West, Kendrick Perkins, Paul Pierce, ...
# 72   (Adam Morrison, Bernard Robinson, Brevin Knigh...
# 115  (Damon Jones, Donyell Marshall, Drew Gooden, L...
#
#                                            away_lineup  count
# 2    (Boris Diaw, Leandro Barbosa, Raja Bell, Shawn...      2
# 36   (Ben Gordon, Ben Wallace, Kirk Hinrich, Luol D...      2
# 59   (Chris Paul, David West, Desmond Mason, Peja S...      2
# 72   (Al Harrington, Danny Granger, Jamaal Tinsley,...      1
# 115  (Antonio Daniels, Brendan Haywood, Caron Butle...      2

# %% [markdown]
# ## 6. Additional Views and Analyses
#
# In this section we implement several analyses to uncover hidden patterns:
#
# 1. **Frequency Analysis by Player Position:** Frequency of players in each home position
# 2. **Outcome Analysis by Home Lineup:** Average outcome (e.g., win/loss) and number of games per lineup
# 3. **Common Home Players Against Specific Away Lineups:** Which home players appear most often against each away lineup
# 4. **Lineup Variation Over Time:** How the number of unique home lineups changes over time

# %% [markdown]
# ### 6.1 Frequency Analysis by Player Position
#
# We calculate how frequently each player appears in each home position (home_0, home_1, etc.).

# %%
# Analyze frequency of players in each home position
for pos in ['home_0', 'home_1', 'home_2', 'home_3', 'home_4']:
    print(f"Frequency for {pos}:")
    print(df_filtered[pos].value_counts().head(10))
    print("---")
# Out:
# Frequency for home_0:
# home_0
# Allen Iverson        657
# Adam Morrison        588
# Amar'e Stoudemire    557
# Andre Iguodala       553
# Chris Wilcox         552
# Anderson Varejao     528
# Danny Granger        511
# Joe Johnson          496
# Antawn Jamison       477
# Al Jefferson         470
# Name: count, dtype: int64
# ---
# Frequency for home_1:
# home_1
# Mark Blount        450
# Eddy Curry         421
# Josh Childress     415
# Ben Wallace        375
# Andre Miller       372
# Baron Davis        365
# Carmelo Anthony    357
# Cuttino Mobley     356
# Chris Bosh         340
# Kobe Bryant        334
# Name: count, dtype: int64
# ---
# Frequency for home_2:
# home_2
# Lamar Odom         337
# Leandro Barbosa    333
# Elton Brand        332
# Marko Jaric        328
# Gerald Wallace     319
# Jamal Crawford     312
# Kirk Hinrich       310
# Erick Dampier      294
# Luther Head        293
# Kyle Korver        292
# Name: count, dtype: int64
# ---
# Frequency for home_3:
# home_3
# Tim Duncan          503
# Shawn Marion        447
# Jason Terry         436
# Mike Dunleavy       402
# LeBron James        372
# Richard Hamilton    371
# Ricky Davis         357
# Luol Deng           353
# Monta Ellis         353
# Nick Collison       349
# Name: count, dtype: int64
# ---
# Frequency for home_4:
# home_4
# Vince Carter       684
# Tony Parker        604
# Josh Howard        601
# Tayshaun Prince    588
# Steve Nash         548
# Zach Randolph      528
# Stephen Jackson    524
# Tyson Chandler     518
# Tim Thomas         495
# Ray Allen          492
# Name: count, dtype: int64
# ---

# %% [markdown]
# ### 6.2 Outcome Analysis by Home Lineup
#
# Here we group by both the home team and home lineup to compute the number of games and the average outcome for each lineup.

# %%
# Outcome analysis by home lineup with home team information
lineup_outcomes = df_filtered.groupby(['home_team', 'home_lineup']).agg(
    games=('game', 'count'),
    avg_outcome=('outcome', 'mean')
).reset_index()

print(lineup_outcomes.sort_values('games', ascending=False).head(10))
# Out:
#      home_team                                        home_lineup  games  \
# 3968       MIN  (Kevin Garnett, Mark Blount, Mike James, Ricky...    126
# 6684       WAS  (Antawn Jamison, Brendan Haywood, Caron Butler...    108
# 6397       UTA  (Andrei Kirilenko, Carlos Boozer, Derek Fisher...    101
# 1521       DAL  (Devin Harris, Dirk Nowitzki, Erick Dampier, J...     96
# 5218       PHO  (Amar'e Stoudemire, Boris Diaw, Raja Bell, Sha...     94
# 1064       CHI  (Ben Gordon, Ben Wallace, Kirk Hinrich, Luol D...     90
# 2365       HOU  (Dikembe Mutombo, Juwan Howard, Rafer Alston, ...     84
# 5260       PHO  (Amar'e Stoudemire, Leandro Barbosa, Raja Bell...     82
# 1953       DET  (Chauncey Billups, Chris Webber, Rasheed Walla...     80
# 4921       ORL  (Dwight Howard, Grant Hill, Hedo Turkoglu, Jam...     79
#
#       avg_outcome
# 3968    -0.301587
# 6684    -0.111111
# 6397    -0.049505
# 1521     0.145833
# 5218    -0.021277
# 1064    -0.177778
# 2365    -0.166667
# 5260    -0.048780
# 1953    -0.225000
# 4921    -0.139241

# %%
# Optionally, view a larger subset sorted by average outcome
lineup_outcomes.head(35).sort_values('avg_outcome', ascending=False)
# Out:
#    home_team                                        home_lineup  games  \
# 24       ATL  (Anthony Johnson, Josh Childress, Marvin Willi...      1
# 15       ATL  (Anthony Johnson, Josh Childress, Josh Smith, ...      1
# 5        ATL  (Anthony Johnson, Joe Johnson, Josh Childress,...      2
# 34       ATL  (Anthony Johnson, Josh Childress, Salim Stouda...      1
# 25       ATL  (Anthony Johnson, Josh Childress, Marvin Willi...      1
# 20       ATL  (Anthony Johnson, Josh Childress, Josh Smith, ...      1
# 18       ATL  (Anthony Johnson, Josh Childress, Josh Smith, ...      4
# 33       ATL  (Anthony Johnson, Josh Childress, Salim Stouda...      3
# 16       ATL  (Anthony Johnson, Josh Childress, Josh Smith, ...     41
# 1        ATL  (Anthony Johnson, Esteban Batista, Marvin Will...      2
# 11       ATL  (Anthony Johnson, Josh Childress, Josh Smith, ...      4
# 17       ATL  (Anthony Johnson, Josh Childress, Josh Smith, ...      2
# 3        ATL  (Anthony Johnson, Joe Johnson, Josh Childress,...      2
# 32       ATL  (Anthony Johnson, Josh Childress, Royal Ivey, ...      2
# 21       ATL  (Anthony Johnson, Josh Childress, Josh Smith, ...      3
# 4        ATL  (Anthony Johnson, Joe Johnson, Josh Childress,...      6
# 12       ATL  (Anthony Johnson, Josh Childress, Josh Smith, ...      7
# 9        ATL  (Anthony Johnson, Joe Johnson, Josh Childress,...      4
# 22       ATL  (Anthony Johnson, Josh Childress, Josh Smith, ...      5
# 2        ATL  (Anthony Johnson, Joe Johnson, Josh Childress,...      3
# 0        ATL  (Anthony Johnson, Esteban Batista, Josh Smith,...      1
# 13       ATL  (Anthony Johnson, Josh Childress, Josh Smith, ...      3
# 14       ATL  (Anthony Johnson, Josh Childress, Josh Smith, ...      5
# 6        ATL  (Anthony Johnson, Joe Johnson, Josh Childress,...      2
# 7        ATL  (Anthony Johnson, Joe Johnson, Josh Childress,...      2
# 8        ATL  (Anthony Johnson, Joe Johnson, Josh Childress,...      1
# 10       ATL  (Anthony Johnson, Joe Johnson, Marvin Williams...      1
# 26       ATL  (Anthony Johnson, Josh Childress, Marvin Willi...      1
# 23       ATL  (Anthony Johnson, Josh Childress, Marvin Willi...      1
# 19       ATL  (Anthony Johnson, Josh Childress, Josh Smith, ...      1
# 27       ATL  (Anthony Johnson, Josh Childress, Marvin Willi...      1
# 30       ATL  (Anthony Johnson, Josh Childress, Marvin Willi...      1
# 29       ATL  (Anthony Johnson, Josh Childress, Marvin Willi...      3
# 28       ATL  (Anthony Johnson, Josh Childress, Marvin Willi...      1
# 31       ATL  (Anthony Johnson, Josh Childress, Marvin Willi...      2
#
#     avg_outcome
# 24     1.000000
# 15     1.000000
# 5      1.000000
# 34     1.000000
# 25     1.000000
# 20     1.000000
# 18     0.500000
# 33     0.333333
# 16     0.073171
# 1      0.000000
# 11     0.000000
# 17     0.000000
# 3      0.000000
# 32     0.000000
# 21    -0.333333
# 4     -0.333333
# 12    -0.428571
# 9     -0.500000
# 22    -0.600000
# 2     -1.000000
# 0     -1.000000
# 13    -1.000000
# 14    -1.000000
# 6     -1.000000
# 7     -1.000000
# 8     -1.000000
# 10    -1.000000
# 26    -1.000000
# 23    -1.000000
# 19    -1.000000
# 27    -1.000000
# 30    -1.000000
# 29    -1.000000
# 28    -1.000000
# 31    -1.000000

# %% [markdown]
# ### 6.3 Most Common Home Players Against Specific Away Lineups
#
# We melt the home player columns to analyze individual player frequencies per away lineup and then sort the results.

# %%
# Melt the home player columns to analyze individual player frequency
home_players = df_filtered.melt(
    id_vars=['game', 'away_lineup', 'date'],
    value_vars=['home_0', 'home_1', 'home_2', 'home_3', 'home_4'],
    var_name='home_position',
    value_name='home_player'
)

# Count the frequency of each home player per away lineup
common_players_vs_away = home_players.groupby(['away_lineup', 'home_player']).size().reset_index(name='count')

# Sort the entire DataFrame by away_lineup and descending count
sorted_common_players = common_players_vs_away.sort_values(['away_lineup', 'count'], ascending=[True, False])

# Display the first 35 rows
sorted_common_players.head(5)
# Out:
#                                          away_lineup  home_player  count
# 0  (Aaron McKie, Andrew Bynum, Brian Cook, Kobe B...  Craig Smith      2
# 1  (Aaron McKie, Andrew Bynum, Brian Cook, Kobe B...  Mark Blount      2
# 5  (Aaron McKie, Andrew Bynum, Brian Cook, Kobe B...  Ricky Davis      2
# 2  (Aaron McKie, Andrew Bynum, Brian Cook, Kobe B...  Marko Jaric      1
# 3  (Aaron McKie, Andrew Bynum, Brian Cook, Kobe B...   Randy Foye      1

# %% [markdown]
# ### 6.4 Lineup Variation Over Time
#
# We merge the unique lineup counts with game dates and examine how the average number of unique home lineups changes over time.

# %%
# Merge the lineup_counts with date information (one record per game)
game_dates = df_filtered[['game', 'date']].drop_duplicates()
lineup_counts = lineup_counts.merge(game_dates, on='game', how='left')

# Aggregate the average number of unique home lineups by date
daily_variation = lineup_counts.groupby('date')['unique_home_lineups'].mean().reset_index()

plt.figure(figsize=(12, 6))
plt.plot(daily_variation['date'], daily_variation['unique_home_lineups'], marker='o')
plt.title('Average Unique Home Lineups Over Time')
plt.xlabel('Date')
plt.ylabel('Average Unique Home Lineups')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Starting Lineup Analysis
#
# Next, we focus on the starting lineups. We extract, for each game, the row with the smallest `starting_min` (the starting lineup) and then determine:
#
# - The **most common starting lineup** for each home team
# - The **most successful starting lineup** (using average outcome as a proxy)
#
# Below we combine these analyses.

# %%
# Extract the starting lineup for each game (using the smallest starting_min per game)
starting_lineups = df_filtered.sort_values('starting_min').groupby('game').first().reset_index()

# Compute frequency and average outcome for each starting lineup by home team
starting_lineup_stats = starting_lineups.groupby(['home_team', 'home_lineup']).agg(
    games_count=('game', 'count'),
    avg_outcome=('outcome', 'mean')
).reset_index()

# For each home team, select the most common starting lineup
idx_common = starting_lineup_stats.groupby('home_team')['games_count'].idxmax()
most_common_starting_lineups = starting_lineup_stats.loc[idx_common].reset_index(drop=True)

print("Most Common Starting Lineups:")
print(most_common_starting_lineups.sort_values('games_count', ascending=False))

# For each home team, select the starting lineup with the highest average outcome
# (Optionally filtering out those with very few appearances)
min_games = 5
team_lineup_success = starting_lineup_stats[starting_lineup_stats['games_count'] >= min_games]
idx_success = team_lineup_success.groupby('home_team')['avg_outcome'].idxmax()
most_successful_starting_lineups = team_lineup_success.loc[idx_success].reset_index(drop=True)

print("\nMost Successful Starting Lineups:")
most_successful_starting_lineups.sort_values('avg_outcome', ascending=False)
# Out:
# Most Common Starting Lineups:
#    home_team                                        home_lineup  games_count  \
# 16       MIN  (Kevin Garnett, Mark Blount, Mike James, Ricky...           26
# 5        DAL  (Devin Harris, Dirk Nowitzki, Erick Dampier, J...           23
# 20       ORL  (Dwight Howard, Grant Hill, Hedo Turkoglu, Jam...           23
# 22       PHO  (Amar'e Stoudemire, Boris Diaw, Raja Bell, Sha...           22
# 3        CHI  (Ben Gordon, Ben Wallace, Kirk Hinrich, Luol D...           20
# 28       UTA  (Andrei Kirilenko, Carlos Boozer, Derek Fisher...           19
# 9        HOU  (Chuck Hayes, Rafer Alston, Shane Battier, Tra...           17
# 7        DET  (Chauncey Billups, Chris Webber, Rasheed Walla...           17
# 29       WAS  (Antawn Jamison, Brendan Haywood, Caron Butler...           17
# 4        CLE  (Drew Gooden, Eric Snow, Larry Hughes, LeBron ...           15
# 18       NOK  (Chris Paul, David West, Desmond Mason, Devin ...           14
# 17       NJN  (Jason Collins, Jason Kidd, Mikki Moore, Richa...           14
# 21       PHI  (Andre Iguodala, Andre Miller, Samuel Dalember...           13
# 12       LAL  (Andrew Bynum, Kobe Bryant, Lamar Odom, Luke W...           13
# 15       MIL  (Andrew Bogut, Brian Skinner, Charlie Bell, Mi...           12
# 25       SAS  (Bruce Bowen, Fabricio Oberto, Manu Ginobili, ...           12
# 11       LAC  (Chris Kaman, Cuttino Mobley, Elton Brand, Qui...           12
# 23       POR  (Brandon Roy, Ime Udoka, Jarrett Jack, Joel Pr...           11
# 26       SEA  (Chris Wilcox, Damien Wilkins, Luke Ridnour, N...           10
# 27       TOR  (Anthony Parker, Chris Bosh, Jorge Garbajosa, ...           10
# 14       MIA  (Eddie Jones, James Posey, Jason Williams, Sha...           10
# 10       IND  (Danny Granger, Jamaal Tinsley, Jermaine O'Nea...            9
# 24       SAC  (Brad Miller, Kenny Thomas, Kevin Martin, Mett...            9
# 6        DEN  (Andre Miller, Carmelo Anthony, Eduardo Najera...            9
# 0        ATL  (Anthony Johnson, Josh Childress, Josh Smith, ...            8
# 19       NYK  (Channing Frye, Eddy Curry, Quentin Richardson...            7
# 1        BOS  (Kendrick Perkins, Paul Pierce, Ryan Gomes, Se...            6
# 8        GSW  (Al Harrington, Andris Biedrins, Baron Davis, ...            6
# 13       MEM  (Damon Stoudamire, Lawrence Roberts, Mike Mill...            5
# 2        CHA  (Emeka Okafor, Gerald Wallace, Matt Carroll, P...            5
#
#     avg_outcome
# 16    -0.076923
# 5      0.304348
# 20     0.217391
# 22     0.363636
# 3      0.400000
# 28    -0.157895
# 9      0.764706
# 7     -0.294118
# 29     0.058824
# 4      0.066667
# 18    -1.000000
# 17    -1.000000
# 21    -0.230769
# 12    -0.076923
# 15    -0.333333
# 25     0.000000
# 11    -0.666667
# 23     0.636364
# 26    -1.000000
# 27     0.200000
# 14    -0.200000
# 10    -0.333333
# 24     0.111111
# 6      0.111111
# 0      0.500000
# 19    -0.428571
# 1      0.000000
# 8      0.333333
# 13    -0.200000
# 2     -1.000000
#
# Most Successful Starting Lineups:
#    home_team                                        home_lineup  games_count  \
# 9        HOU  (Chuck Hayes, Rafer Alston, Shane Battier, Tra...           17
# 20       ORL  (Dwight Howard, Hedo Turkoglu, Jameer Nelson, ...            6
# 25       SAS  (Bruce Bowen, Francisco Elson, Michael Finley,...            6
# 23       POR  (Brandon Roy, Ime Udoka, Jarrett Jack, Joel Pr...           11
# 8        GSW  (Al Harrington, Baron Davis, Jason Richardson,...            5
# 5        DAL  (Dirk Nowitzki, Erick Dampier, Greg Buckner, J...            5
# 19       NYK  (Channing Frye, Eddy Curry, Jamal Crawford, Ja...            5
# 12       LAL  (Andrew Bynum, Brian Cook, Kobe Bryant, Luke W...            5
# 0        ATL  (Anthony Johnson, Josh Childress, Josh Smith, ...            8
# 3        CHI  (Andres Nocioni, Ben Wallace, Chris Duhon, Kir...           15
# 11       LAC  (Chris Kaman, Corey Maggette, Cuttino Mobley, ...            7
# 22       PHO  (Amar'e Stoudemire, Boris Diaw, Raja Bell, Sha...           22
# 27       TOR  (Anthony Parker, Chris Bosh, Jorge Garbajosa, ...            6
# 4        CLE  (Drew Gooden, Larry Hughes, LeBron James, Sash...           11
# 24       SAC  (Brad Miller, John Salmons, Kenny Thomas, Kevi...            5
# 1        BOS  (Al Jefferson, Delonte West, Gerald Green, Ken...            5
# 7        DET  (Chauncey Billups, Nazr Mohammed, Rasheed Wall...           12
# 6        DEN  (Andre Miller, Carmelo Anthony, Eduardo Najera...            9
# 29       WAS  (Antawn Jamison, Brendan Haywood, Caron Butler...           17
# 14       MIA  (Alonzo Mourning, Dorell Wright, Dwyane Wade, ...            6
# 16       MIN  (Kevin Garnett, Mark Blount, Mike James, Ricky...           26
# 28       UTA  (Andrei Kirilenko, Carlos Boozer, Derek Fisher...           19
# 13       MEM  (Damon Stoudamire, Lawrence Roberts, Mike Mill...            5
# 21       PHI  (Andre Iguodala, Andre Miller, Rodney Carney, ...           10
# 15       MIL  (Andrew Bogut, Brian Skinner, Charlie Bell, Mi...           12
# 10       IND  (Danny Granger, Jamaal Tinsley, Jermaine O'Nea...            9
# 2        CHA  (Emeka Okafor, Gerald Wallace, Matt Carroll, P...            5
# 17       NJN  (Antoine Wright, Jason Collins, Jason Kidd, Mi...            6
# 18       NOK  (Chris Paul, David West, Desmond Mason, Devin ...           14
# 26       SEA  (Chris Wilcox, Damien Wilkins, Luke Ridnour, N...           10
#
#     avg_outcome
# 9      0.764706
# 20     0.666667
# 25     0.666667
# 23     0.636364
# 8      0.600000
# 5      0.600000
# 19     0.600000
# 12     0.600000
# 0      0.500000
# 3      0.466667
# 11     0.428571
# 22     0.363636
# 27     0.333333
# 4      0.272727
# 24     0.200000
# 1      0.200000
# 7      0.166667
# 6      0.111111
# 29     0.058824
# 14     0.000000
# 16    -0.076923
# 28    -0.157895
# 13    -0.200000
# 21    -0.200000
# 15    -0.333333
# 10    -0.333333
# 2     -1.000000
# 17    -1.000000
# 18    -1.000000
# 26    -1.000000

# %% [markdown]
# ## 8. Minutes Played Analysis
#
# We now calculate the minutes played by each home player using only the `starting_min` values. In each game, the duration of a lineup segment is calculated as the difference between the current row’s `starting_min` and the next row’s `starting_min`. For the final segment of a game, we use the game length (48 minutes) minus the current `starting_min`. Note that a player may change positions during the game; this approach accounts for that by melting all home lineup columns.

# %%
# Sort the DataFrame by game and starting_min
df_sorted = df_filtered.sort_values(['game', 'starting_min']).copy()

# Compute the duration for each lineup segment per game
# For each game, duration = next starting_min - current starting_min
# For the last segment in each game, duration = 48 - current starting_min
df_sorted['duration'] = df_sorted.groupby('game')['starting_min'].transform(lambda x: x.shift(-1) - x)
df_sorted['duration'] = df_sorted['duration'].fillna(48 - df_sorted['starting_min'])

# Melt the home lineup columns so that each row corresponds to a player's appearance in that segment
home_players = df_sorted.melt(
    id_vars=['game', 'home_team', 'duration'],
    value_vars=['home_0', 'home_1', 'home_2', 'home_3', 'home_4'],
    var_name='position',
    value_name='player'
)

# Group by home_team and player to sum the durations (minutes played)
player_minutes = home_players.groupby(['home_team', 'player'])['duration'].sum().reset_index()
player_minutes.rename(columns={'duration': 'total_minutes'}, inplace=True)

# For each team, select the top 5 players by minutes played
top5_by_team = (
    player_minutes.sort_values(['home_team', 'total_minutes'], ascending=[True, False])
    .groupby('home_team')
    .head(5)
    .reset_index(drop=True)
)

print(top5_by_team)
# Out:
#     home_team             player  total_minutes
# 0         ATL         Josh Smith         1322.0
# 1         ATL        Joe Johnson         1120.0
# 2         ATL    Marvin Williams         1107.0
# 3         ATL     Josh Childress         1077.0
# 4         ATL      Zaza Pachulia         1034.0
# ..        ...                ...            ...
# 145       WAS     Gilbert Arenas         1459.0
# 146       WAS       Caron Butler         1319.0
# 147       WAS     Antawn Jamison         1290.0
# 148       WAS  DeShawn Stevenson         1256.0
# 149       WAS    Brendan Haywood          890.0
#
# [150 rows x 3 columns]

# %%
# Extract home players, including season information, and rename the team column
home_players = df_filtered.melt(
    id_vars=['game', 'season', 'home_team'],
    value_vars=['home_0', 'home_1', 'home_2', 'home_3', 'home_4'],
    var_name='position',
    value_name='player'
).rename(columns={'home_team': 'team'})

# Extract away players, including season information, and rename the team column
away_players = df_filtered.melt(
    id_vars=['game', 'season', 'away_team'],
    value_vars=['away_0', 'away_1', 'away_2', 'away_3', 'away_4'],
    var_name='position',
    value_name='player'
).rename(columns={'away_team': 'team'})

# Combine home and away players into one DataFrame
all_players = pd.concat(
    [home_players[['game', 'season', 'team', 'player']], 
     away_players[['game', 'season', 'team', 'player']]],
    ignore_index=True
)

# Group by team and season to get unique players for each team in each season
team_players = all_players.groupby(['team', 'season'])['player'].unique().reset_index()

# Optionally, convert the array of players to a sorted, comma-separated string for easier reading
team_players['players'] = team_players['player'].apply(lambda x: ', '.join(sorted(x)))
team_players = team_players[['team', 'season', 'players']]

team_players
# Out:
#    team  season  \
# 0   ATL    2007
# 1   BOS    2007
# 2   CHA    2007
# 3   CHI    2007
# 4   CLE    2007
# 5   DAL    2007
# 6   DEN    2007
# 7   DET    2007
# 8   GSW    2007
# 9   HOU    2007
# 10  IND    2007
# 11  LAC    2007
# 12  LAL    2007
# 13  MEM    2007
# 14  MIA    2007
# 15  MIL    2007
# 16  MIN    2007
# 17  NJN    2007
# 18  NOK    2007
# 19  NYK    2007
# 20  ORL    2007
# 21  PHI    2007
# 22  PHO    2007
# 23  POR    2007
# 24  SAC    2007
# 25  SAS    2007
# 26  SEA    2007
# 27  TOR    2007
# 28  UTA    2007
# 29  WAS    2007
#
#                                                                                                                                                                                                                                                                                                                 players
# 0           Anthony Johnson, Cedric Bozeman, Dijon Thompson, Esteban Batista, Jeremy Richardson, Joe Johnson, Josh Childress, Josh Smith, Lorenzen Wright, Marvin Williams, Matt Freije, Royal Ivey, Salim Stoudamire, Shelden Williams, Solomon Jones, Speedy Claxton, Stanislav Medvedenko, Tyronn Lue, Zaza Pachulia
# 1                                                                           Al Jefferson, Allan Ray, Brian Scalabrine, Delonte West, Gerald Green, Kendrick Perkins, Kevinn Pinkney, Leon Powe, Michael Olowokandi, Paul Pierce, Rajon Rondo, Ryan Gomes, Sebastian Telfair, Theo Ratliff, Tony Allen, Wally Szczerbiak
# 2                                          Adam Morrison, Alan Anderson, Bernard Robinson, Brevin Knight, Derek Anderson, Emeka Okafor, Eric Williams, Gerald Wallace, Jake Voskuhl, Jeff McInnis, Matt Carroll, Melvin Ely, Othella Harrington, Primoz Brezec, Raymond Felton, Ryan Hollins, Sean May, Walter Herrmann
# 3                                                                                                                   Adrian Griffin, Andre Barrett, Andres Nocioni, Ben Gordon, Ben Wallace, Chris Duhon, Kirk Hinrich, Luol Deng, Malik Allen, Mike Sweetney, P.J. Brown, Thabo Sefolosha, Tyrus Thomas, Viktor Khryapa
# 4                                                                                           Anderson Varejao, Damon Jones, Daniel Gibson, David Wesley, Donyell Marshall, Drew Gooden, Dwayne Jones, Eric Snow, Ira Newble, Larry Hughes, LeBron James, Sasha Pavlovic, Scot Pollard, Shannon Brown, Zydrunas Ilgauskas
# 5                                                                 Anthony Johnson, Austin Croshere, DeSagana Diop, Devean George, Devin Harris, Didier Ilunga-Mbenga, Dirk Nowitzki, Erick Dampier, Greg Buckner, J.J. Barea, Jason Terry, Jerry Stackhouse, Josh Howard, Kevin Willis, Maurice Ager, Pops Mensah-Bonsu
# 6                                                 Allen Iverson, Andre Miller, Anthony Carter, Carmelo Anthony, DerMarr Johnson, Earl Boykins, Eduardo Najera, J.R. Smith, Jamal Sampson, Joe Smith, Julius Hodge, Kenyon Martin, Linas Kleiza, Marcus Camby, Nene Hilario, Reggie Evans, Steve Blake, Yakhouba Diawara
# 7                                                                               Amir Johnson, Antonio McDyess, Carlos Delfino, Chauncey Billups, Chris Webber, Dale Davis, Jason Maxiell, Lindsey Hunter, Nazr Mohammed, Rasheed Wallace, Richard Hamilton, Ronald Dupree, Ronald Murray, Tayshaun Prince, Will Blalock
# 8   Adonal Foyle, Al Harrington, Andris Biedrins, Anthony Roberson, Baron Davis, Dajuan Wagner, Ike Diogu, Jason Richardson, Josh Powell, Keith McLeod, Kelenna Azubuike, Matt Barnes, Mickael Pietrus, Mike Dunleavy, Monta Ellis, Patrick O'Bryant, Renaldo Major, Sarunas Jasikevicius, Stephen Jackson, Troy Murphy
# 9                                                                                              Bonzi Wells, Chuck Hayes, Dikembe Mutombo, Jake Tsakalidis, John Lucas III, Juwan Howard, Kirk Snyder, Luther Head, Rafer Alston, Scott Padgett, Shane Battier, Steve Novak, Tracy McGrady, Vassilis Spanoulis, Yao Ming
# 10                 Al Harrington, Danny Granger, Darrell Armstrong, David Harrison, Ike Diogu, Jamaal Tinsley, Jeff Foster, Jermaine O'Neal, Josh Powell, Keith McLeod, Maceo Baston, Marquis Daniels, Mike Dunleavy, Orien Greene, Rawle Marshall, Sarunas Jasikevicius, Shawne Williams, Stephen Jackson, Troy Murphy
# 11                                                 Aaron Williams, Alvin Williams, Chris Kaman, Corey Maggette, Cuttino Mobley, Daniel Ewing, Doug Christie, Elton Brand, James Singleton, Jason Hart, Luke Jackson, Paul Davis, Quinton Ross, Sam Cassell, Shaun Livingston, Tim Thomas, Will Conroy, Yaroslav Korolev
# 12                                                                                                            Aaron McKie, Andrew Bynum, Brian Cook, Jordan Farmar, Kobe Bryant, Kwame Brown, Lamar Odom, Luke Walton, Maurice Evans, Ronny Turiaf, Sasha Vujacic, Shammond Williams, Smush Parker, Vladimir Radmanovic
# 13                                        Alexander Johnson, Brian Cardinal, Chucky Atkins, Dahntay Jones, Damon Stoudamire, Eddie Jones, Hakim Warrick, Jake Tsakalidis, Junior Harrington, Kyle Lowry, Lawrence Roberts, Mike Miller, Pau Gasol, Rudy Gay, Scott Padgett, Stromile Swift, Tarence Kinsey, Will Conroy
# 14                                                                               Alonzo Mourning, Antoine Walker, Chris Quinn, Dorell Wright, Dwyane Wade, Earl Barron, Eddie Jones, Gary Payton, James Posey, Jason Kapono, Jason Williams, Michael Doleac, Robert Hite, Shaquille O'Neal, Udonis Haslem, Wayne Simien
# 15                                                                  Andrew Bogut, Brian Skinner, Charlie Bell, Charlie Villanueva, Chris McCray, Damir Markota, Dan Gadzuric, David Noel, Earl Boykins, Ersan Ilyasova, Jared Reiner, Julius Hodge, Lynn Greer, Michael Redd, Mo Williams, Ruben Patterson, Steve Blake
# 16                                                                                                                      Bracey Wright, Craig Smith, Eddie Griffin, Justin Reed, Kevin Garnett, Mark Blount, Mark Madsen, Marko Jaric, Mike James, Randy Foye, Rashad McCants, Ricky Davis, Trenton Hassell, Troy Hudson
# 17                                                                                       Antoine Wright, Bernard Robinson, Bostjan Nachbar, Clifford Robinson, Eddie House, Hassan Adams, Jason Collins, Jason Kidd, Josh Boone, Marcus Williams, Mikki Moore, Mile Ilic, Nenad Krstic, Richard Jefferson, Vince Carter
# 18                                                                                      Bobby Jackson, Brandon Bass, Cedric Simmons, Chris Paul, David West, Desmond Mason, Devin Brown, Hilton Armstrong, Jannero Pargo, Linton Johnson, Marc Jackson, Marcus Vinicius, Peja Stojakovic, Rasual Butler, Tyson Chandler
# 19                                                                                      Channing Frye, David Lee, Eddy Curry, Jamal Crawford, Jared Jeffries, Jerome James, Kelvin Cato, Malik Rose, Mardy Collins, Nate Robinson, Quentin Richardson, Randolph Morris, Renaldo Balkman, Stephon Marbury, Steve Francis
# 20                                                                                                   Bo Outlaw, Carlos Arroyo, Darko Milicic, Dwight Howard, Grant Hill, Hedo Turkoglu, J.J. Redick, Jameer Nelson, James Augustine, Keith Bogans, Keyon Dooling, Pat Garrity, Tony Battie, Travis Diener, Trevor Ariza
# 21                                                 Alan Henderson, Allen Iverson, Andre Iguodala, Andre Miller, Bobby Jones, Chris Webber, Ivan McFarlin, Joe Smith, Kevin Ollie, Kyle Korver, Lou Amundson, Lou Williams, Rodney Carney, Samuel Dalembert, Shavlik Randolph, Steven Hunter, Steven Smith, Willie Green
# 22                                                                                                                       Amar'e Stoudemire, Boris Diaw, Eric Piatkowski, Jalen Rose, James Jones, Jumaine Jones, Kurt Thomas, Leandro Barbosa, Marcus Banks, Pat Burke, Raja Bell, Sean Marks, Shawn Marion, Steve Nash
# 23                                                                        Brandon Roy, Dan Dickau, Fred Jones, Ime Udoka, Jamaal Magloire, Jarrett Jack, Joel Przybilla, Juan Dixon, LaMarcus Aldridge, Luke Schenscher, Martell Webster, Raef LaFrentz, Sergio Rodriguez, Stephen Graham, Travis Outlaw, Zach Randolph
# 24                                                                           Brad Miller, Corliss Williamson, Francisco Garcia, Jason Hart, John Salmons, Justin Williams, Kenny Thomas, Kevin Martin, Maurice Taylor, Metta World Peace, Mike Bibby, Quincy Douby, Ronnie Price, Shareef Abdur-Rahim, Vitaly Potapenko
# 25                                                                                      Beno Udrih, Brent Barry, Bruce Bowen, Eric Williams, Fabricio Oberto, Francisco Elson, Jackie Butler, Jacque Vaughn, James White, Manu Ginobili, Matt Bonner, Melvin Ely, Michael Finley, Robert Horry, Tim Duncan, Tony Parker
# 26                                                                         Andre Brown, Andreas Glyniadakis, Chris Wilcox, Damien Wilkins, Danny Fortson, Desmon Farmer, Earl Watson, Johan Petro, Luke Ridnour, Mickael Gelabale, Mike Wilks, Mouhamed Sene, Nick Collison, Randy Livingston, Rashard Lewis, Ray Allen
# 27                                                                     Andrea Bargnani, Anthony Parker, Chris Bosh, Darrick Martin, Fred Jones, Joey Graham, Jorge Garbajosa, Jose Calderon, Juan Dixon, Kris Humphries, Luke Jackson, Morris Peterson, P.J. Tucker, Pape Sow, Rasho Nesterovic, T.J. Ford, Uros Slokar
# 28                                                                                             Andrei Kirilenko, C.J. Miles, Carlos Boozer, Dee Brown, Derek Fisher, Deron Williams, Gordan Giricek, Jarron Collins, Lou Amundson, Matt Harpring, Mehmet Okur, Paul Millsap, Rafael Araujo, Roger Powell, Ronnie Brewer
# 29                                                                       Andray Blatche, Antawn Jamison, Antonio Daniels, Brendan Haywood, Calvin Booth, Caron Butler, Darius Songaila, DeShawn Stevenson, Donell Taylor, Etan Thomas, Gilbert Arenas, James Lang, Jarvis Hayes, Michael Ruffin, Mike Hall, Roger Mason

# %% [markdown]
# ## 9. Conclusions and Next Steps
#
# We have now organized our exploratory analysis and generated several views:
#
# - **Data Loading and Preparation:** Inspection, filtering, and date extraction
# - **Lineup Analysis:** Creation of lineup tuples, counting unique lineups, and identifying the most frequent and successful lineups
# - **Additional Views:** Frequency by position, outcome analysis, common matchup analysis, and temporal variation
# - **Starting Lineup & Minutes Played:** Analysis of starting lineups and calculation of playing time by aggregating lineup segment durations
#
# These insights will guide further feature engineering—such as adding a "lineup stability" score or incorporating network centrality measures—to improve the accuracy, precision, and recall of our missing-player prediction model.
#
# Next steps might include:
#
# - Deepening the analysis by linking external data (e.g., player positions or roles)
# - Applying clustering or association rule mining to detect common player combinations
# - Testing different predictive models with the engineered features
#
# Feel free to extend or modify this analysis as needed.
