# %% [markdown]
# # Exploratory Data Analysis for NBA Lineup Prediction and Hidden Patterns
#
# This notebook organizes the data exploration steps from the raw CSV file and then implements several additional views to uncover hidden patterns. We aim to understand:
#
# - **Lineup stability and variation** over time
# - **Frequency of player appearances** in different positions (home_0 to home_4)
# - **Outcome analysis** by lineup
# - **Common matchups:** which home players appear most frequently against certain away lineups
#
# These insights can guide further feature engineering to improve our predictive model.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import resample
from sklearn.preprocessing import LabelEncoder, StandardScaler

import joblib
from sklearn.model_selection import train_test_split, KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# For warnings
import warnings
warnings.filterwarnings('ignore')

# Set display options for Pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

pd.option_context('display.max_rows', None, 'display.max_columns', None)

# %% [markdown]
# ## 1. Load and Inspect the Raw Data
#
# Here we load a sample raw CSV file (2007 - 2015 season) and inspect its contents.

# %%
# Define the folder containing the CSV files (update the path as needed)
data_folder = "../data"  # Replace with your actual data folder path

# Load all CSV files from 2007 to 2015
csv_files = sorted(glob.glob(os.path.join(data_folder, "matchups-20*.csv")))
dfs = []
for file in csv_files:
    print(f"Loading {file}")
    df = pd.read_csv(file)
    dfs.append(df)

df_all_years = pd.concat(dfs, ignore_index=True)

# Define the allowed features
allowed_features = [
    'game', 'season', 'home_team', 'away_team', 'starting_min',
    'home_0', 'home_1', 'home_2', 'home_3', 'home_4',
    'away_0', 'away_1', 'away_2', 'away_3', 'away_4',
    'outcome'  
]

# Filter the dataframe
df_filtered = df_all_years[allowed_features].copy()


# Dictionary to map old team acronyms to their new ones
team_acronym_mapping = {
    "NJN": "BRK",   # New Jersey Nets → Brooklyn Nets
    "NOK": "NOP",   # New Orleans/Oklahoma City Hornets → New Orleans Pelicans
    "NOH": "NOP",    # New Orleans Hornets → New Orleans Pelicans
    "CHO": "CHA",   # fix charlotte hornets 
    "SEA": "OKC"    # sonics become okc
}

# Apply the mapping to the home_team column
df_filtered["home_team"] = df_filtered["home_team"].replace(team_acronym_mapping)

df_filtered["away_team"] = df_filtered["away_team"].replace(team_acronym_mapping)



# Create lineup tuples (sorted alphabetically for consistency)
df_filtered['home_lineup'] = df_filtered[['home_0', 'home_1', 'home_2', 'home_3', 'home_4']].apply(lambda x: tuple(sorted(x)), axis=1)
df_filtered['away_lineup'] = df_filtered[['away_0', 'away_1', 'away_2', 'away_3', 'away_4']].apply(lambda x: tuple(sorted(x)), axis=1)

df_filtered_concat = df_filtered[['game', 'season', 'home_team', 'away_team', 'starting_min', 'home_lineup', 'away_lineup', 'outcome']]
# Out:
# Loading ../data\matchups-2007.csv
# Loading ../data\matchups-2008.csv
# Loading ../data\matchups-2009.csv
# Loading ../data\matchups-2010.csv
# Loading ../data\matchups-2011.csv
# Loading ../data\matchups-2012.csv
# Loading ../data\matchups-2013.csv
# Loading ../data\matchups-2014.csv
# Loading ../data\matchups-2015.csv

# %% [markdown]
# ## 4. Unique Lineup Counts per Game
#
# We group by game and count how many unique home and away lineups were used.

# %%
# Count unique lineups per game
lineup_counts = df_filtered.groupby('game').agg(
    unique_home_lineups=('home_lineup', 'nunique'),
    unique_away_lineups=('away_lineup', 'nunique')
).reset_index()

lineup_counts.head()
# Out:
#            game  unique_home_lineups  unique_away_lineups
# 0  200610310LAL                   11                    9
# 1  200610310MIA                   11                   16
# 2  200611010BOS                   19                   17
# 3  200611010CHA                   16                   15
# 4  200611010CLE                   12                   10

# %%
unique_games = df_all_years['game'].nunique()
print("Total unique games:", unique_games)
# Out:
# Total unique games: 10828

# %% [markdown]
# ## 5. Most Frequently Used Lineups per Game
#
# We now identify the most frequently used home and away lineups for each game.

# %%
# Sort the DataFrame by game and starting_min
df_sorted = df_filtered.sort_values(['game', 'starting_min']).copy()

# Compute the duration for each lineup segment per game.
# For each game, duration = next starting_min - current starting_min.
# For the last segment in each game, duration = 48 - current starting_min.
df_sorted['duration'] = df_sorted.groupby('game')['starting_min'].transform(lambda x: x.shift(-1) - x)
df_sorted['duration'] = df_sorted['duration'].fillna(48 - df_sorted['starting_min'])

# Group by the lineup combination and sum the duration (total minutes played)
lineup_usage = df_sorted.groupby(
    ['game', 'home_team', 'away_team', 
     'home_0', 'home_1', 'home_2', 'home_3', 'home_4',
     'away_0', 'away_1', 'away_2', 'away_3', 'away_4', 
     'home_lineup', 'away_lineup']
)['duration'].sum().reset_index(name='total_minutes')

# Sort the DataFrame by game and total_minutes in descending order
most_used_lineups = lineup_usage.sort_values(['game', 'total_minutes'], ascending=[True, False])
display(most_used_lineups.head())
# Out:
#            game home_team away_team        home_0         home_1       home_2  \
# 8  200610310LAL       LAL       PHO    Brian Cook  Jordan Farmar   Lamar Odom
# 5  200610310LAL       LAL       PHO  Andrew Bynum     Lamar Odom  Luke Walton
# 2  200610310LAL       LAL       PHO  Andrew Bynum     Lamar Odom  Luke Walton
# 3  200610310LAL       LAL       PHO  Andrew Bynum     Lamar Odom  Luke Walton
# 1  200610310LAL       LAL       PHO  Andrew Bynum     Lamar Odom  Luke Walton
#
#           home_3               home_4       away_0           away_1  \
# 8  Sasha Vujacic  Vladimir Radmanovic   Boris Diaw      James Jones
# 5  Sasha Vujacic         Smush Parker   Boris Diaw      Kurt Thomas
# 2  Maurice Evans         Smush Parker   Boris Diaw  Leandro Barbosa
# 3  Maurice Evans         Smush Parker  Kurt Thomas  Leandro Barbosa
# 1  Maurice Evans         Smush Parker   Boris Diaw      Kurt Thomas
#
#         away_2           away_3        away_4  \
# 8  Kurt Thomas  Leandro Barbosa  Marcus Banks
# 5    Raja Bell     Shawn Marion    Steve Nash
# 2    Raja Bell     Shawn Marion    Steve Nash
# 3    Raja Bell     Shawn Marion    Steve Nash
# 1    Raja Bell     Shawn Marion    Steve Nash
#
#                                                                    home_lineup  \
# 8  (Brian Cook, Jordan Farmar, Lamar Odom, Sasha Vujacic, Vladimir Radmanovic)
# 5         (Andrew Bynum, Lamar Odom, Luke Walton, Sasha Vujacic, Smush Parker)
# 2         (Andrew Bynum, Lamar Odom, Luke Walton, Maurice Evans, Smush Parker)
# 3         (Andrew Bynum, Lamar Odom, Luke Walton, Maurice Evans, Smush Parker)
# 1         (Andrew Bynum, Lamar Odom, Luke Walton, Maurice Evans, Smush Parker)
#
#                                                              away_lineup  \
# 8  (Boris Diaw, James Jones, Kurt Thomas, Leandro Barbosa, Marcus Banks)
# 5         (Boris Diaw, Kurt Thomas, Raja Bell, Shawn Marion, Steve Nash)
# 2     (Boris Diaw, Leandro Barbosa, Raja Bell, Shawn Marion, Steve Nash)
# 3    (Kurt Thomas, Leandro Barbosa, Raja Bell, Shawn Marion, Steve Nash)
# 1         (Boris Diaw, Kurt Thomas, Raja Bell, Shawn Marion, Steve Nash)
#
#    total_minutes
# 8            7.0
# 5            6.0
# 2            5.0
# 3            4.0
# 1            3.0

# %% [markdown]
# ## 6. Additional Views and Analyses
#
# In this section, we implement several new views to uncover hidden patterns:
#
# 1. **Frequency Analysis by Player Position:** How often does each player appear in a given home position (home_0, home_1, etc.)?
# 2. **Outcome Analysis by Home Lineup:** What are the win/loss outcomes (or average outcome) for different home lineups?
# 3. **Common Home Players Against Specific Away Lineups:** Which home players are most frequently used against a given away lineup?
# 4. **Lineup Variation Over Time:** How does the number of unique lineups change over time?

# %% [markdown]
# ### 6.1 Frequency Analysis by Player Position

# %%
# Analyze frequency of players in each home position
for pos in ['home_0', 'home_1', 'home_2', 'home_3', 'home_4']:
    print(f"Frequency for {pos}:")
    print(df_filtered[pos].value_counts().head(10))
    print("---")
# Out:
# Frequency for home_0:
# home_0
# Andre Iguodala       5150
# Al Jefferson         4492
# Amar'e Stoudemire    3804
# Boris Diaw           3502
# Al Horford           3340
# Al Harrington        3129
# Beno Udrih           2951
# Andrew Bogut         2652
# Anderson Varejao     2650
# Andray Blatche       2532
# Name: count, dtype: int64
# ---
# Frequency for home_1:
# home_1
# Dwyane Wade        2468
# Carmelo Anthony    2446
# David West         2433
# Dirk Nowitzki      2258
# Dwight Howard      2216
# Andre Miller       2139
# Deron Williams     2029
# David Lee          1985
# Kevin Durant       1983
# Jamal Crawford     1982
# Name: count, dtype: int64
# ---
# Frequency for home_2:
# home_2
# LaMarcus Aldridge    2340
# Josh Smith           2114
# LeBron James         1864
# J.R. Smith           1846
# Kobe Bryant          1821
# Jarrett Jack         1815
# Deron Williams       1763
# Paul Pierce          1761
# Lamar Odom           1721
# Mike Conley          1706
# Name: count, dtype: int64
# ---
# Frequency for home_3:
# home_3
# Tim Duncan       3281
# Monta Ellis      2688
# Rajon Rondo      2298
# Pau Gasol        2104
# LeBron James     2073
# Shawn Marion     2069
# Mike Dunleavy    2044
# Paul Millsap     2041
# Jason Terry      2011
# Luol Deng        1991
# Name: count, dtype: int64
# ---
# Frequency for home_4:
# home_4
# Tony Parker       4478
# Vince Carter      4332
# Zach Randolph     4219
# Tyson Chandler    3757
# Trevor Ariza      3438
# Steve Nash        3230
# Tyreke Evans      3146
# Thaddeus Young    3028
# Udonis Haslem     3014
# Zaza Pachulia     2985
# Name: count, dtype: int64
# ---

# %%
# Analyze occurrences of a specific player in each home position
player_name = "LeBron James"

for pos in ['home_0', 'home_1', 'home_2', 'home_3', 'home_4']:
    count = (df_filtered[pos] == player_name).sum()
    print(f"{player_name} appears in {pos}: {count} times")
# Out:
# LeBron James appears in home_0: 130 times
# LeBron James appears in home_1: 853 times
# LeBron James appears in home_2: 1864 times
# LeBron James appears in home_3: 2073 times
# LeBron James appears in home_4: 740 times

# %% [markdown]
# ### 6.2 Outcome Analysis by Home Lineup
#
# We group by the home lineup and calculate the average outcome and the number of games for each unique lineup. (Note: The `outcome` column typically indicates win/loss; you may need to adjust if using different metrics.)

# %%
# Ensure the dataset is sorted by game and starting_min
df_sorted = df_filtered.sort_values(['game', 'starting_min']).copy()

# Compute the duration of each lineup segment for each game.
# For each game, duration = next starting_min - current starting_min.
# For the last segment in each game, duration = 48 - current starting_min.
df_sorted['duration'] = df_sorted.groupby('game')['starting_min'].transform(lambda x: x.shift(-1) - x)
df_sorted['duration'] = df_sorted['duration'].fillna(48 - df_sorted['starting_min'])

# Group by season, home_team, and lineup columns to compute:
# - games: number of segments (or games) in which the lineup was used
# - avg_outcome: the average outcome for those segments
# - total_time: the sum of durations (i.e., total minutes played) for that lineup
lineup_outcomes = df_sorted.groupby(
    ['season', 'home_team', 'home_0', 'home_1', 'home_2', 'home_3', 'home_4', 'home_lineup']
).agg(
    games=('game', 'count'),
    avg_outcome=('outcome', 'mean'),
    total_time=('duration', 'sum')
).reset_index()

# Sort the results by season, then home_team, then by number of games (descending)
all_lineup_outcomes = lineup_outcomes.sort_values(['season', 'home_team', 'games'])

all_lineup_outcomes.head()
# Out:
#     season home_team           home_0           home_1           home_2  \
# 0     2007       ATL  Anthony Johnson  Esteban Batista       Josh Smith
# 8     2007       ATL  Anthony Johnson      Joe Johnson   Josh Childress
# 10    2007       ATL  Anthony Johnson      Joe Johnson  Marvin Williams
# 15    2007       ATL  Anthony Johnson   Josh Childress       Josh Smith
# 19    2007       ATL  Anthony Johnson   Josh Childress       Josh Smith
#
#               home_3          home_4  \
# 0         Royal Ivey   Solomon Jones
# 8    Marvin Williams      Tyronn Lue
# 10     Solomon Jones  Speedy Claxton
# 15   Marvin Williams      Tyronn Lue
# 19  Shelden Williams   Solomon Jones
#
#                                                                        home_lineup  \
# 0        (Anthony Johnson, Esteban Batista, Josh Smith, Royal Ivey, Solomon Jones)
# 8      (Anthony Johnson, Joe Johnson, Josh Childress, Marvin Williams, Tyronn Lue)
# 10  (Anthony Johnson, Joe Johnson, Marvin Williams, Solomon Jones, Speedy Claxton)
# 15      (Anthony Johnson, Josh Childress, Josh Smith, Marvin Williams, Tyronn Lue)
# 19  (Anthony Johnson, Josh Childress, Josh Smith, Shelden Williams, Solomon Jones)
#
#     games  avg_outcome  total_time
# 0       1         -1.0         1.0
# 8       1         -1.0         4.0
# 10      1         -1.0         3.0
# 15      1          1.0         1.0
# 19      1         -1.0         2.0

# %% [markdown]
# ### 6.3 Most Common Home Players Against Specific Away Lineups
#
# For each unique away lineup, we analyze which home players appear most frequently. Here we melt the home player columns into one long format and then group by away lineup and player.

# %%
# Melt the home player columns to analyze individual player frequency per team per season
home_players = df_filtered.melt(
    id_vars=['season', 'game', 'home_team', 'away_team', 'away_lineup'],
    value_vars=['home_0', 'home_1', 'home_2', 'home_3', 'home_4'],
    var_name='home_position',
    value_name='home_player'
)

# Count the frequency of each home player per away lineup, per team, and per season
players_vs_away_count = home_players.groupby(['season', 'home_team', 'away_team', 'away_lineup', 'home_player']).size().reset_index(name='count')

# Sort by frequency of occurrence
players_vs_away_count = players_vs_away_count.sort_values(['season', 'count'], ascending=[True, False])


players_vs_away_count.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 745798 entries, 19254 to 745797
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   season       745798 non-null  int64
#  1   home_team    745798 non-null  object
#  2   away_team    745798 non-null  object
#  3   away_lineup  745798 non-null  object
#  4   home_player  745798 non-null  object
#  5   count        745798 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 39.8+ MB

# %%
players_vs_away_count.head()
# Out:
#        season home_team away_team  \
# 19254    2007       DAL       MIN
# 19259    2007       DAL       MIN
# 21529    2007       DEN       HOU
# 42488    2007       MEM       MIN
# 10735    2007       CHA       NYK
#
#                                                                        away_lineup  \
# 19254       (Kevin Garnett, Mark Blount, Mike James, Ricky Davis, Trenton Hassell)
# 19259       (Kevin Garnett, Mark Blount, Mike James, Ricky Davis, Trenton Hassell)
# 21529  (Dikembe Mutombo, Juwan Howard, Rafer Alston, Shane Battier, Tracy McGrady)
# 42488       (Kevin Garnett, Mark Blount, Mike James, Ricky Davis, Trenton Hassell)
# 10735        (Eddy Curry, Malik Rose, Mardy Collins, Nate Robinson, Steve Francis)
#
#            home_player  count
# 19254    Dirk Nowitzki     15
# 19259      Josh Howard     13
# 21529    Allen Iverson     13
# 42488      Mike Miller     13
# 10735  Walter Herrmann     12

# %% [markdown]
# We have now organized the initial exploratory code and extended our analysis with additional views:
#
# - **Frequency by Position:** Reveals which players appear most frequently in each home position.
# - **Outcome Analysis:** Shows the performance (win/loss average) of different home lineups.
# - **Common Matchups:** Identifies which home players are used most often against particular away lineups.

# %%
# Extract the starting lineup for each game (row with the smallest starting_min per game)
starting_lineups = df_filtered.sort_values('starting_min').groupby(['season', 'game']).first().reset_index()

# Group by season, home_team, and home_lineup to compute number of games and the average outcome
starting_lineup_stats = starting_lineups.groupby(['season', 'home_team', 'home_lineup']).agg(
    games_count=('game', 'count'),
    avg_outcome=('outcome', 'mean')
).reset_index()

# For each season and home_team, select the lineup with the maximum games_count (most frequently used lineup)
idx = starting_lineup_stats.groupby(['season', 'home_team'])['games_count'].idxmax()
most_common_starting_lineups = starting_lineup_stats.loc[idx].reset_index(drop=True)

# Sort results to see the most used lineups first
most_common_starting_lineups = most_common_starting_lineups.sort_values(['season', 'games_count'], ascending=[True, False])

most_common_starting_lineups.sort_values('season', ascending=True).head()
# Out:
#     season home_team  \
# 17    2007       MIN
# 6     2007       DAL
# 21    2007       ORL
# 23    2007       PHO
# 4     2007       CHI
#
#                                                                home_lineup  \
# 17  (Kevin Garnett, Mark Blount, Mike James, Ricky Davis, Trenton Hassell)
# 6   (Devin Harris, Dirk Nowitzki, Erick Dampier, Jason Terry, Josh Howard)
# 21  (Dwight Howard, Grant Hill, Hedo Turkoglu, Jameer Nelson, Tony Battie)
# 23    (Amar'e Stoudemire, Boris Diaw, Raja Bell, Shawn Marion, Steve Nash)
# 4           (Ben Gordon, Ben Wallace, Kirk Hinrich, Luol Deng, P.J. Brown)
#
#     games_count  avg_outcome
# 17           26    -0.076923
# 6            23     0.304348
# 21           23     0.217391
# 23           22     0.363636
# 4            20     0.400000

# %%
# Group by season, home_team, and home_lineup to calculate the number of games and average outcome
team_lineup_success = df_filtered.groupby(['season', 'home_team', 'home_lineup']).agg(
    games=('game', 'count'),
    avg_outcome=('outcome', 'mean')
).reset_index()

# Optionally, filter out lineups with very few appearances to avoid outliers
min_games = 5  # Adjust threshold as needed
team_lineup_success = team_lineup_success[team_lineup_success['games'] >= min_games]

# For each season and home_team, select the lineup with the highest average outcome
idx = team_lineup_success.groupby(['season', 'home_team'])['avg_outcome'].idxmax()
most_successful_lineups = team_lineup_success.loc[idx].reset_index(drop=True)

# Sort results for easier reading (by season and success rate)
most_successful_lineups = most_successful_lineups.sort_values(['season', 'avg_outcome'], ascending=[True, False])

# Display the final DataFrame
most_successful_lineups.head()
# Out:
#     season home_team  \
# 13    2007       LAL
# 25    2007       SAC
# 4     2007       CHI
# 27    2007       TOR
# 1     2007       BOS
#
#                                                                    home_lineup  \
# 13   (Kobe Bryant, Lamar Odom, Ronny Turiaf, Sasha Vujacic, Shammond Williams)
# 25   (Brad Miller, Corliss Williamson, John Salmons, Kevin Martin, Mike Bibby)
# 4          (Adrian Griffin, Ben Wallace, Chris Duhon, Kirk Hinrich, Luol Deng)
# 27  (Chris Bosh, Joey Graham, Jorge Garbajosa, Jose Calderon, Morris Peterson)
# 1      (Allan Ray, Gerald Green, Kevinn Pinkney, Leon Powe, Sebastian Telfair)
#
#     games  avg_outcome
# 13      5     1.000000
# 25      5     1.000000
# 4       7     0.714286
# 27      7     0.714286
# 1       6     0.666667

# %%
# Extract home players, including season information, and rename the team column
home_players = df_filtered.melt(
    id_vars=['game', 'season', 'home_team'],
    value_vars=['home_0', 'home_1', 'home_2', 'home_3', 'home_4'],
    var_name='position',
    value_name='player'
).rename(columns={'home_team': 'team'})

# Extract away players, including season information, and rename the team column
away_players = df_filtered.melt(
    id_vars=['game', 'season', 'away_team'],
    value_vars=['away_0', 'away_1', 'away_2', 'away_3', 'away_4'],
    var_name='position',
    value_name='player'
).rename(columns={'away_team': 'team'})

# Combine home and away players into one DataFrame
all_players = pd.concat(
    [home_players[['game', 'season', 'team', 'player']], 
     away_players[['game', 'season', 'team', 'player']]],
    ignore_index=True
)

# Group by team and season to get unique players for each team in each season
team_players = all_players.groupby(['team', 'season'])['player'].unique().reset_index()

# Optionally, convert the array of players to a sorted, comma-separated string for easier reading
team_players['players'] = team_players['player'].apply(lambda x: ', '.join(sorted(x)))
team_players = team_players[['team', 'season', 'players']]

team_players.head()
# Out:
#   team  season  \
# 0  ATL    2007
# 1  ATL    2008
# 2  ATL    2009
# 3  ATL    2010
# 4  ATL    2011
#
#                                                                                                                                                                                                                                                                                                        players
# 0  Anthony Johnson, Cedric Bozeman, Dijon Thompson, Esteban Batista, Jeremy Richardson, Joe Johnson, Josh Childress, Josh Smith, Lorenzen Wright, Marvin Williams, Matt Freije, Royal Ivey, Salim Stoudamire, Shelden Williams, Solomon Jones, Speedy Claxton, Stanislav Medvedenko, Tyronn Lue, Zaza Pachulia
# 1                                                                    Acie Law, Al Horford, Anthony Johnson, Jeremy Richardson, Joe Johnson, Josh Childress, Josh Smith, Lorenzen Wright, Mario West, Marvin Williams, Mike Bibby, Salim Stoudamire, Shelden Williams, Solomon Jones, Tyronn Lue, Zaza Pachulia
# 2                                                                                          Acie Law, Al Horford, Joe Johnson, Josh Smith, Mario West, Marvin Williams, Maurice Evans, Mike Bibby, Othello Hunter, Randolph Morris, Ronald Murray, Solomon Jones, Speedy Claxton, Thomas Gardner, Zaza Pachulia
# 3                                                                                                           Al Horford, Jamal Crawford, Jason Collins, Jeff Teague, Joe Johnson, Joe Smith, Josh Smith, Mario West, Marvin Williams, Maurice Evans, Mike Bibby, Othello Hunter, Randolph Morris, Zaza Pachulia
# 4                                                               Al Horford, Damien Wilkins, Etan Thomas, Hilton Armstrong, Jamal Crawford, Jason Collins, Jeff Teague, Joe Johnson, Jordan Crawford, Josh Powell, Josh Smith, Kirk Hinrich, Marvin Williams, Maurice Evans, Mike Bibby, Pape Sy, Zaza Pachulia

# %%
# Melt the home player columns to analyze player participation
home_players = df_filtered.melt(
    id_vars=['game', 'season', 'home_team'],
    value_vars=['home_0', 'home_1', 'home_2', 'home_3', 'home_4'],
    var_name='home_position',
    value_name='player'
).rename(columns={'home_team': 'team'})

# Melt the away player columns
away_players = df_filtered.melt(
    id_vars=['game', 'season', 'away_team'],
    value_vars=['away_0', 'away_1', 'away_2', 'away_3', 'away_4'],
    var_name='away_position',
    value_name='player'
).rename(columns={'away_team': 'team'})

# Combine both home and away players into one DataFrame
all_players = pd.concat(
    [home_players[['game', 'season', 'team', 'player']], 
     away_players[['game', 'season', 'team', 'player']]],
    ignore_index=True
)

# Count how many games each player appeared in for each team in each season
player_game_counts = all_players.groupby(['season', 'team', 'player'])['game'].nunique().reset_index()

# Rename the column for clarity
player_game_counts.rename(columns={'game': 'games_played'}, inplace=True)

# Sort the results for better readability
player_game_counts = player_game_counts.sort_values(['season', 'team', 'games_played'], ascending=[True, True, False])


player_game_counts.head()
# Out:
#     season team            player  games_played
# 13    2007  ATL  Shelden Williams            81
# 7     2007  ATL        Josh Smith            72
# 18    2007  ATL     Zaza Pachulia            72
# 8     2007  ATL   Lorenzen Wright            67
# 9     2007  ATL   Marvin Williams            64

# %%
# First, aggregate unique players by team and season without converting to string
team_players_df = all_players.groupby(['team', 'season'])['player'].unique().reset_index()

# Convert the 'player' column (which is an array) to a list for each row
team_players_df['player'] = team_players_df['player'].apply(list)

# Now, build a nested dictionary: {team: {season: [players]}}
rosters_dict = {}
for _, row in team_players_df.iterrows():
    team = row['team']
    season = row['season']
    players_list = row['player']
    if team not in rosters_dict:
        rosters_dict[team] = {}
    rosters_dict[team][season] = sorted(players_list)  # sorted for consistency

# %%
# --- Compute Minutes Played by Each Player for Both Home and Away ---

# Sort the filtered DataFrame by game and starting_min, then compute the duration for each lineup segment.
df_sorted = df_filtered.sort_values(['game', 'starting_min']).copy()
# Duration is the difference between the current starting_min and the next one in the same game;
# for the last segment in each game, use (48 - current starting_min)
df_sorted['duration'] = df_sorted.groupby('game')['starting_min'].transform(lambda x: x.shift(-1) - x)
df_sorted['duration'] = df_sorted['duration'].fillna(48 - df_sorted['starting_min'])

# --- Compute minutes for home players ---
# Melt the home player columns to long format.
home_players = df_sorted.melt(
    id_vars=['game', 'season', 'home_team', 'duration'],
    value_vars=['home_0', 'home_1', 'home_2', 'home_3', 'home_4'],
    var_name='position',
    value_name='player'
)
# Rename the team column for consistency.
home_players = home_players.rename(columns={'home_team': 'team'})

# --- Compute minutes for away players ---
# Melt the away player columns similarly.
away_players = df_sorted.melt(
    id_vars=['game', 'season', 'away_team', 'duration'],
    value_vars=['away_0', 'away_1', 'away_2', 'away_3', 'away_4'],
    var_name='position',
    value_name='player'
)
away_players = away_players.rename(columns={'away_team': 'team'})

# Combine the two DataFrames
all_players_minutes = pd.concat([home_players[['game', 'season', 'team', 'player', 'duration']],
                                 away_players[['game', 'season', 'team', 'player', 'duration']]],
                                ignore_index=True)

# Group by team, season, and player to get total minutes played.
player_minutes = (
    all_players_minutes.groupby(['team', 'season', 'player'])['duration']
    .sum()
    .reset_index()
    .rename(columns={'duration': 'total_minutes'})
)

# Optional: sort for readability
player_minutes = player_minutes.sort_values(['team', 'season', 'total_minutes'], ascending=[True, True, False])
display(player_minutes)

# --- Build a Roster Dictionary Including Minutes Played ---
# This dictionary will have the structure:
# { team: { season: { player: total_minutes, ... }, ... }, ... }

rosters_with_minutes = {}
for _, row in player_minutes.iterrows():
    team = row['team']
    season = row['season']
    player = row['player']
    minutes = row['total_minutes']
    if team not in rosters_with_minutes:
        rosters_with_minutes[team] = {}
    if season not in rosters_with_minutes[team]:
        rosters_with_minutes[team][season] = {}
    rosters_with_minutes[team][season][player] = minutes
# Out:
#      team  season           player  total_minutes
# 7     ATL    2007       Josh Smith         2637.0
# 5     ATL    2007      Joe Johnson         2355.0
# 9     ATL    2007  Marvin Williams         2181.0
# 18    ATL    2007    Zaza Pachulia         2019.0
# 6     ATL    2007   Josh Childress         1982.0
# ...   ...     ...              ...            ...
# 4721  WAS    2015  Martell Webster          330.0
# 4713  WAS    2015     DeJuan Blair          153.0
# 4728  WAS    2015       Will Bynum           57.0
# 4716  WAS    2015        Glen Rice           42.0
# 4727  WAS    2015     Toure' Murry           15.0
#
# [4729 rows x 4 columns]

# %%
#Example of using the dictionary

rosters_with_minutes['TOR'][2015]
# Out:
# {'Kyle Lowry': 2412.0,
#  'Jonas Valanciunas': 2154.0,
#  'DeMar DeRozan': 2117.0,
#  'Terrence Ross': 2087.0,
#  'Patrick Patterson': 2073.0,
#  'Amir Johnson': 1983.0,
#  'Greivis Vasquez': 1958.0,
#  'Lou Williams': 1949.0,
#  'James Johnson': 1356.0,
#  'Tyler Hansbrough': 1047.0,
#  'Chuck Hayes': 254.0,
#  'Landry Fields': 206.0,
#  'Greg Stiemsma': 50.0,
#  'Lucas Nogueira': 18.0,
#  'Bruno Caboclo': 16.0}

# %%
# --- Calculate minutes played by each player on each team for each season ---

# Sort the DataFrame by game and starting_min, then compute the duration for each lineup segment.
df_sorted = df_filtered.sort_values(['game', 'starting_min']).copy()
df_sorted['duration'] = df_sorted.groupby('game')['starting_min'].transform(lambda x: x.shift(-1) - x)
df_sorted['duration'] = df_sorted['duration'].fillna(48 - df_sorted['starting_min'])

# Melt the home player columns so each row corresponds to a player's appearance in a lineup segment.
# This includes the game, season, home_team, and duration (minutes played in that segment).
home_players = df_sorted.melt(
    id_vars=['game', 'season', 'home_team', 'duration'],
    value_vars=['home_0', 'home_1', 'home_2', 'home_3', 'home_4'],
    var_name='position',
    value_name='player'
)

# Group by team, season, and player to calculate the total minutes played.
player_minutes = home_players.groupby(['home_team', 'season', 'player'])['duration'].sum().reset_index()
player_minutes.rename(columns={'duration': 'total_minutes'}, inplace=True)

# Sort the results for easier reading.
player_minutes = player_minutes.sort_values(['home_team', 'season', 'total_minutes'], ascending=[True, True, False])

# Display the complete DataFrame
display(player_minutes.head())
# Out:
#    home_team  season           player  total_minutes
# 7        ATL    2007       Josh Smith         1322.0
# 5        ATL    2007      Joe Johnson         1120.0
# 9        ATL    2007  Marvin Williams         1107.0
# 6        ATL    2007   Josh Childress         1077.0
# 18       ATL    2007    Zaza Pachulia         1034.0

# %% [markdown]
# END ANALYSIS

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder

# =============================================================================
# STEP 1: Compute Duration for Each Lineup Segment
# =============================================================================
df_sorted = df_filtered.sort_values(['game', 'starting_min']).copy()
df_sorted['duration'] = df_sorted.groupby('game')['starting_min'].transform(lambda x: x.shift(-1) - x)
df_sorted['duration'] = df_sorted['duration'].fillna(48 - df_sorted['starting_min'])

# =============================================================================
# STEP 2: Compute Mean Encoding for Home & Away Players
# =============================================================================
home_players = df_sorted.melt(
    id_vars=['game', 'season', 'home_team', 'duration', 'outcome'],
    value_vars=['home_0', 'home_1', 'home_2', 'home_3', 'home_4'],
    var_name='position',
    value_name='player'
).rename(columns={'home_team': 'team'})

away_players = df_sorted.melt(
    id_vars=['game', 'season', 'away_team', 'duration', 'outcome'],
    value_vars=['away_0', 'away_1', 'away_2', 'away_3', 'away_4'],
    var_name='position',
    value_name='player'
).rename(columns={'away_team': 'team'})

# Compute Weighted Outcome for Home/Away Players
home_players['weighted_outcome'] = home_players['outcome'] * home_players['duration']
away_players['weighted_outcome'] = (1 - away_players['outcome']) * away_players['duration']

# Aggregate Mean Encoding for Players by Season & Team
def compute_player_encoding(df):
    player_outcome = df.groupby(['season', 'team', 'player']).agg(
        total_weighted_outcome=('weighted_outcome', 'sum'),
        total_minutes=('duration', 'sum')
    ).reset_index()
    player_outcome['base_mean_encoding'] = player_outcome['total_weighted_outcome'] / player_outcome['total_minutes']
    return player_outcome

player_encoding_home = compute_player_encoding(home_players)
player_encoding_away = compute_player_encoding(away_players)

# Build Dictionary for Fast Lookup
mean_encoding_dict_home = dict(zip(
    zip(player_encoding_home['season'], player_encoding_home['team'], player_encoding_home['player']),
    player_encoding_home['base_mean_encoding']
))

mean_encoding_dict_away = dict(zip(
    zip(player_encoding_away['season'], player_encoding_away['team'], player_encoding_away['player']),
    player_encoding_away['base_mean_encoding']
))

# Compute Team Average Encoding for 2015 as a fallback
team_avg_encoding_away = player_encoding_away[player_encoding_away['season'] == 2015].groupby('team')['base_mean_encoding'].mean().to_dict()

# Compute Fallback Mean Encoding
overall_fallback = df_sorted['outcome'].mean()

# =============================================================================
# STEP 3: Apply Mean Encoding to Training Data
# =============================================================================
df_encoded = df_sorted.copy()

def encode_player(row, col, mean_dict, team_col):
    """Encodes a player using the correct team column (home or away)."""
    key = (row['season'], row[team_col], row[col])  # Select home_team or away_team
    return mean_dict.get(key, overall_fallback)

# Apply correct encoding for home players (using 'home_team')
for col in ['home_0', 'home_1', 'home_2', 'home_3', 'home_4']:
    df_encoded[col] = df_encoded.apply(lambda row: encode_player(row, col, mean_encoding_dict_home, 'home_team'), axis=1)

# Apply correct encoding for away players (using 'away_team')
for col in ['away_0', 'away_1', 'away_2', 'away_3', 'away_4']:
    df_encoded[col] = df_encoded.apply(lambda row: encode_player(row, col, mean_encoding_dict_away, 'away_team'), axis=1)

# =============================================================================
# FIX: Improved Away Lineup Encoding
# =============================================================================
def encode_away_lineup(row):
    """
    Compute the mean encoding for the away lineup.
    If a player is missing in 2016, check 2015 data.
    If still missing, use 2015 team mean encoding.
    If no team data exists, use overall fallback.
    """
    encodings = []
    
    for col in ['away_0', 'away_1', 'away_2', 'away_3', 'away_4']:
        player = row[col]
        season = row['season']
        team = row['away_team']

        # Try to get player encoding from 2016
        key = (season, team, player)
        if key in mean_encoding_dict_away:
            encodings.append(mean_encoding_dict_away[key])
            continue

        # Try to get player encoding from 2015 (any team)
        key_2015 = (2015, team, player)
        if key_2015 in mean_encoding_dict_away:
            encodings.append(mean_encoding_dict_away[key_2015])
            continue

        # Use the 2015 team average encoding
        if team in team_avg_encoding_away:
            encodings.append(team_avg_encoding_away[team])
            continue

        # If nothing found, use overall fallback
        encodings.append(overall_fallback)
    
    # Compute the final away lineup encoding (ignore NaNs)
    return np.nanmean(encodings)

# Apply the fixed encoding function
df_encoded['away_lineup_encoded'] = df_encoded.apply(encode_away_lineup, axis=1)

print("✅ Training Data Ready! Away lineup encoding fixed.")
# Out:
# ✅ Training Data Ready! Away lineup encoding fixed.

# %%
df_encoded
# Out:
#                 game  season home_team away_team  starting_min    home_0  \
# 0       200610310LAL    2007       LAL       PHO             0 -0.135498
# 1       200610310LAL    2007       LAL       PHO             6 -0.135498
# 2       200610310LAL    2007       LAL       PHO             8 -0.134421
# 3       200610310LAL    2007       LAL       PHO            10 -0.134421
# 4       200610310LAL    2007       LAL       PHO            11 -0.134525
# ...              ...     ...       ...       ...           ...       ...
# 215481  201504150TOR    2015       TOR       CHA            25 -0.110507
# 215482  201504150TOR    2015       TOR       CHA            35 -0.110507
# 215483  201504150TOR    2015       TOR       CHA            37 -0.159585
# 215484  201504150TOR    2015       TOR       CHA            45 -0.159585
# 215485  201504150TOR    2015       TOR       CHA            46 -0.159585
#
#           home_1    home_2    home_3    home_4    away_0    away_1    away_2  \
# 0      -0.134421 -0.134525 -0.024876 -0.136656  1.317518  1.305921  1.320178
# 1      -0.134421 -0.134525 -0.024876 -0.136656  1.324006  1.329084  1.320178
# 2      -0.134525 -0.078710 -0.094262 -0.136656  1.324006  1.329084  1.320178
# 3      -0.134525 -0.078710 -0.094262 -0.136656  1.317518  1.299248  1.305921
# 4      -0.078710 -0.094262 -0.136656 -0.211679  1.317518  1.299248  1.305921
# ...          ...       ...       ...       ...       ...       ...       ...
# 215481 -0.123468 -0.106383 -0.114259 -0.007812  0.953795  0.989655  0.820513
# 215482 -0.169072 -0.123468 -0.160731 -0.114259  0.953795  0.989655  0.972549
# 215483 -0.169072 -0.162242 -0.106383 -0.160731  1.100324  1.025532  0.820513
# 215484 -0.169072 -0.106383 -0.160731 -0.114259  0.953795  1.100324  0.820513
# 215485 -0.110507 -0.169072 -0.160731 -0.114259  0.953795  1.100324  0.820513
#
#           away_3    away_4  outcome  \
# 0       1.325813  1.318551       -1
# 1       1.325813  1.318551       -1
# 2       1.325813  1.318551        1
# 3       1.329084  1.290043        1
# 4       1.329084  1.290043       -1
# ...          ...       ...      ...
# 215481  0.972549  1.020325        1
# 215482  1.025316  0.976744        1
# 215483  1.025316  0.976744       -1
# 215484  1.025316  0.976744       -1
# 215485  1.025316  0.976744       -1
#
#                                                                                   home_lineup  \
# 0                        (Andrew Bynum, Lamar Odom, Luke Walton, Sasha Vujacic, Smush Parker)
# 1                        (Andrew Bynum, Lamar Odom, Luke Walton, Sasha Vujacic, Smush Parker)
# 2                        (Lamar Odom, Luke Walton, Maurice Evans, Ronny Turiaf, Smush Parker)
# 3                        (Lamar Odom, Luke Walton, Maurice Evans, Ronny Turiaf, Smush Parker)
# 4               (Luke Walton, Maurice Evans, Ronny Turiaf, Smush Parker, Vladimir Radmanovic)
# ...                                                                                       ...
# 215481        (DeMar DeRozan, Jonas Valanciunas, Kyle Lowry, Terrence Ross, Tyler Hansbrough)
# 215482  (DeMar DeRozan, Greivis Vasquez, Jonas Valanciunas, Patrick Patterson, Terrence Ross)
# 215483          (Amir Johnson, Greivis Vasquez, James Johnson, Kyle Lowry, Patrick Patterson)
# 215484          (Amir Johnson, Greivis Vasquez, Kyle Lowry, Patrick Patterson, Terrence Ross)
# 215485       (Amir Johnson, DeMar DeRozan, Greivis Vasquez, Patrick Patterson, Terrence Ross)
#
#                                                                                away_lineup  \
# 0                           (Boris Diaw, Kurt Thomas, Raja Bell, Shawn Marion, Steve Nash)
# 1                (Amar'e Stoudemire, Leandro Barbosa, Raja Bell, Shawn Marion, Steve Nash)
# 2                (Amar'e Stoudemire, Leandro Barbosa, Raja Bell, Shawn Marion, Steve Nash)
# 3                    (Boris Diaw, James Jones, Kurt Thomas, Leandro Barbosa, Marcus Banks)
# 4                    (Boris Diaw, James Jones, Kurt Thomas, Leandro Barbosa, Marcus Banks)
# ...                                                                                    ...
# 215481  (Bismack Biyombo, Gerald Henderson, Jeffery Taylor, Kemba Walker, Marvin Williams)
# 215482        (Bismack Biyombo, Gerald Henderson, Kemba Walker, Noah Vonleh, Troy Daniels)
# 215483           (Brian Roberts, Jason Maxiell, Jeffery Taylor, Noah Vonleh, Troy Daniels)
# 215484         (Bismack Biyombo, Brian Roberts, Jeffery Taylor, Noah Vonleh, Troy Daniels)
# 215485         (Bismack Biyombo, Brian Roberts, Jeffery Taylor, Noah Vonleh, Troy Daniels)
#
#         duration  away_lineup_encoded
# 0            6.0             1.123045
# 1            2.0             1.123045
# 2            2.0             1.123045
# 3            1.0             1.123045
# 4            1.0             1.123045
# ...          ...                  ...
# 215481      10.0             1.018073
# 215482       2.0             1.018073
# 215483       8.0             1.018073
# 215484       1.0             1.018073
# 215485       2.0             1.018073
#
# [236912 rows x 20 columns]

# %%
# =============================================================================
# STEP 5: Create Training Data by Simulating Missingness
# =============================================================================
training_rows = []
for idx, enc_row in df_encoded.iterrows():
    raw_row = df_filtered.loc[idx]  # Using raw data for true player names
    for pos in range(5):
        feature_row = enc_row.copy()
        feature_row['missing_position'] = pos
        feature_row['missing_player'] = raw_row[f'home_{pos}']
        # Instead of dropping the column, we set the value to NaN to simulate missingness.
        feature_row[f'home_{pos}'] = np.nan
        training_rows.append(feature_row)

df_train = pd.DataFrame(training_rows).reset_index(drop=True)

# %%
#uncomment and run this cell only if the complete training data already exists in the data folder

#df_train.to_csv("../data/train_updated_3.csv", index=False)

# %%
df_train = pd.read_csv("../data/train_updated_3.csv")

# %%
# =============================================================================
# 🔹 NEW: Build Team-Player Lookup Dictionary for Filtering Predictions
# =============================================================================
team_player_dict = df_train.groupby(['season', 'home_team'])['missing_player'].unique().apply(set).to_dict()

print("✅ Data Preparation Complete! df_encoded is ready.")
# Out:
# ✅ Data Preparation Complete! df_encoded is ready.

# %%
df_encoded
# Out:
#                 game  season home_team away_team  starting_min    home_0  \
# 0       200610310LAL    2007       LAL       PHO             0 -0.135498
# 1       200610310LAL    2007       LAL       PHO             6 -0.135498
# 2       200610310LAL    2007       LAL       PHO             8 -0.134421
# 3       200610310LAL    2007       LAL       PHO            10 -0.134421
# 4       200610310LAL    2007       LAL       PHO            11 -0.134525
# ...              ...     ...       ...       ...           ...       ...
# 215481  201504150TOR    2015       TOR       CHA            25 -0.110507
# 215482  201504150TOR    2015       TOR       CHA            35 -0.110507
# 215483  201504150TOR    2015       TOR       CHA            37 -0.159585
# 215484  201504150TOR    2015       TOR       CHA            45 -0.159585
# 215485  201504150TOR    2015       TOR       CHA            46 -0.159585
#
#           home_1    home_2    home_3    home_4    away_0    away_1    away_2  \
# 0      -0.134421 -0.134525 -0.024876 -0.136656  1.317518  1.305921  1.320178
# 1      -0.134421 -0.134525 -0.024876 -0.136656  1.324006  1.329084  1.320178
# 2      -0.134525 -0.078710 -0.094262 -0.136656  1.324006  1.329084  1.320178
# 3      -0.134525 -0.078710 -0.094262 -0.136656  1.317518  1.299248  1.305921
# 4      -0.078710 -0.094262 -0.136656 -0.211679  1.317518  1.299248  1.305921
# ...          ...       ...       ...       ...       ...       ...       ...
# 215481 -0.123468 -0.106383 -0.114259 -0.007812  0.953795  0.989655  0.820513
# 215482 -0.169072 -0.123468 -0.160731 -0.114259  0.953795  0.989655  0.972549
# 215483 -0.169072 -0.162242 -0.106383 -0.160731  1.100324  1.025532  0.820513
# 215484 -0.169072 -0.106383 -0.160731 -0.114259  0.953795  1.100324  0.820513
# 215485 -0.110507 -0.169072 -0.160731 -0.114259  0.953795  1.100324  0.820513
#
#           away_3    away_4  outcome  \
# 0       1.325813  1.318551       -1
# 1       1.325813  1.318551       -1
# 2       1.325813  1.318551        1
# 3       1.329084  1.290043        1
# 4       1.329084  1.290043       -1
# ...          ...       ...      ...
# 215481  0.972549  1.020325        1
# 215482  1.025316  0.976744        1
# 215483  1.025316  0.976744       -1
# 215484  1.025316  0.976744       -1
# 215485  1.025316  0.976744       -1
#
#                                                                                   home_lineup  \
# 0                        (Andrew Bynum, Lamar Odom, Luke Walton, Sasha Vujacic, Smush Parker)
# 1                        (Andrew Bynum, Lamar Odom, Luke Walton, Sasha Vujacic, Smush Parker)
# 2                        (Lamar Odom, Luke Walton, Maurice Evans, Ronny Turiaf, Smush Parker)
# 3                        (Lamar Odom, Luke Walton, Maurice Evans, Ronny Turiaf, Smush Parker)
# 4               (Luke Walton, Maurice Evans, Ronny Turiaf, Smush Parker, Vladimir Radmanovic)
# ...                                                                                       ...
# 215481        (DeMar DeRozan, Jonas Valanciunas, Kyle Lowry, Terrence Ross, Tyler Hansbrough)
# 215482  (DeMar DeRozan, Greivis Vasquez, Jonas Valanciunas, Patrick Patterson, Terrence Ross)
# 215483          (Amir Johnson, Greivis Vasquez, James Johnson, Kyle Lowry, Patrick Patterson)
# 215484          (Amir Johnson, Greivis Vasquez, Kyle Lowry, Patrick Patterson, Terrence Ross)
# 215485       (Amir Johnson, DeMar DeRozan, Greivis Vasquez, Patrick Patterson, Terrence Ross)
#
#                                                                                away_lineup  \
# 0                           (Boris Diaw, Kurt Thomas, Raja Bell, Shawn Marion, Steve Nash)
# 1                (Amar'e Stoudemire, Leandro Barbosa, Raja Bell, Shawn Marion, Steve Nash)
# 2                (Amar'e Stoudemire, Leandro Barbosa, Raja Bell, Shawn Marion, Steve Nash)
# 3                    (Boris Diaw, James Jones, Kurt Thomas, Leandro Barbosa, Marcus Banks)
# 4                    (Boris Diaw, James Jones, Kurt Thomas, Leandro Barbosa, Marcus Banks)
# ...                                                                                    ...
# 215481  (Bismack Biyombo, Gerald Henderson, Jeffery Taylor, Kemba Walker, Marvin Williams)
# 215482        (Bismack Biyombo, Gerald Henderson, Kemba Walker, Noah Vonleh, Troy Daniels)
# 215483           (Brian Roberts, Jason Maxiell, Jeffery Taylor, Noah Vonleh, Troy Daniels)
# 215484         (Bismack Biyombo, Brian Roberts, Jeffery Taylor, Noah Vonleh, Troy Daniels)
# 215485         (Bismack Biyombo, Brian Roberts, Jeffery Taylor, Noah Vonleh, Troy Daniels)
#
#         duration  away_lineup_encoded
# 0            6.0             1.123045
# 1            2.0             1.123045
# 2            2.0             1.123045
# 3            1.0             1.123045
# 4            1.0             1.123045
# ...          ...                  ...
# 215481      10.0             1.018073
# 215482       2.0             1.018073
# 215483       8.0             1.018073
# 215484       1.0             1.018073
# 215485       2.0             1.018073
#
# [236912 rows x 20 columns]

# %%
# ==========================================================================================================================================================
# STEP 6: Compute Lineup Averages (the home team lineup average will be calculated without the value of the redacted player)
# ==========================================================================================================================================================

df_train['home_lineup_avg'] = df_train[['home_0', 'home_1', 'home_2', 'home_3', 'home_4']].mean(axis=1)

df_train['away_lineup_avg'] = df_train[['away_0', 'away_1', 'away_2', 'away_3', 'away_4']].mean(axis=1)
df_train.head(3)
# Out:
#            game  season home_team away_team  starting_min    home_0    home_1  \
# 0  200610310LAL    2007       LAL       PHO             0       NaN -0.134421
# 1  200610310LAL    2007       LAL       PHO             0 -0.135498       NaN
# 2  200610310LAL    2007       LAL       PHO             0 -0.135498 -0.134421
#
#      home_2    home_3    home_4    away_0    away_1    away_2    away_3  \
# 0 -0.134525 -0.024876 -0.136656  1.317518  1.305921  1.320178  1.325813
# 1 -0.134525 -0.024876 -0.136656  1.317518  1.305921  1.320178  1.325813
# 2       NaN -0.024876 -0.136656  1.317518  1.305921  1.320178  1.325813
#
#      away_4  outcome  \
# 0  1.318551       -1
# 1  1.318551       -1
# 2  1.318551       -1
#
#                                                                       home_lineup  \
# 0  ('Andrew Bynum', 'Lamar Odom', 'Luke Walton', 'Sasha Vujacic', 'Smush Parker')
# 1  ('Andrew Bynum', 'Lamar Odom', 'Luke Walton', 'Sasha Vujacic', 'Smush Parker')
# 2  ('Andrew Bynum', 'Lamar Odom', 'Luke Walton', 'Sasha Vujacic', 'Smush Parker')
#
#                                                                 away_lineup  \
# 0  ('Boris Diaw', 'Kurt Thomas', 'Raja Bell', 'Shawn Marion', 'Steve Nash')
# 1  ('Boris Diaw', 'Kurt Thomas', 'Raja Bell', 'Shawn Marion', 'Steve Nash')
# 2  ('Boris Diaw', 'Kurt Thomas', 'Raja Bell', 'Shawn Marion', 'Steve Nash')
#
#    duration  away_lineup_encoded  missing_position missing_player  \
# 0       6.0             1.123045                 0   Andrew Bynum
# 1       6.0             1.123045                 1     Lamar Odom
# 2       6.0             1.123045                 2    Luke Walton
#
#    home_lineup_avg  away_lineup_avg
# 0        -0.107619         1.317596
# 1        -0.107889         1.317596
# 2        -0.107863         1.317596

# %%
df_train
# Out:
#                  game  season home_team away_team  starting_min    home_0  \
# 0        200610310LAL    2007       LAL       PHO             0       NaN
# 1        200610310LAL    2007       LAL       PHO             0 -0.135498
# 2        200610310LAL    2007       LAL       PHO             0 -0.135498
# 3        200610310LAL    2007       LAL       PHO             0 -0.135498
# 4        200610310LAL    2007       LAL       PHO             0 -0.135498
# ...               ...     ...       ...       ...           ...       ...
# 1184555  201504150TOR    2015       TOR       CHA            46       NaN
# 1184556  201504150TOR    2015       TOR       CHA            46 -0.159585
# 1184557  201504150TOR    2015       TOR       CHA            46 -0.159585
# 1184558  201504150TOR    2015       TOR       CHA            46 -0.159585
# 1184559  201504150TOR    2015       TOR       CHA            46 -0.159585
#
#            home_1    home_2    home_3    home_4    away_0    away_1    away_2  \
# 0       -0.134421 -0.134525 -0.024876 -0.136656  1.317518  1.305921  1.320178
# 1             NaN -0.134525 -0.024876 -0.136656  1.317518  1.305921  1.320178
# 2       -0.134421       NaN -0.024876 -0.136656  1.317518  1.305921  1.320178
# 3       -0.134421 -0.134525       NaN -0.136656  1.317518  1.305921  1.320178
# 4       -0.134421 -0.134525 -0.024876       NaN  1.317518  1.305921  1.320178
# ...           ...       ...       ...       ...       ...       ...       ...
# 1184555 -0.110507 -0.169072 -0.160731 -0.114259  0.953795  1.100324  0.820513
# 1184556       NaN -0.169072 -0.160731 -0.114259  0.953795  1.100324  0.820513
# 1184557 -0.110507       NaN -0.160731 -0.114259  0.953795  1.100324  0.820513
# 1184558 -0.110507 -0.169072       NaN -0.114259  0.953795  1.100324  0.820513
# 1184559 -0.110507 -0.169072 -0.160731       NaN  0.953795  1.100324  0.820513
#
#            away_3    away_4  outcome  \
# 0        1.325813  1.318551       -1
# 1        1.325813  1.318551       -1
# 2        1.325813  1.318551       -1
# 3        1.325813  1.318551       -1
# 4        1.325813  1.318551       -1
# ...           ...       ...      ...
# 1184555  1.025316  0.976744       -1
# 1184556  1.025316  0.976744       -1
# 1184557  1.025316  0.976744       -1
# 1184558  1.025316  0.976744       -1
# 1184559  1.025316  0.976744       -1
#
#                                                                                         home_lineup  \
# 0                    ('Andrew Bynum', 'Lamar Odom', 'Luke Walton', 'Sasha Vujacic', 'Smush Parker')
# 1                    ('Andrew Bynum', 'Lamar Odom', 'Luke Walton', 'Sasha Vujacic', 'Smush Parker')
# 2                    ('Andrew Bynum', 'Lamar Odom', 'Luke Walton', 'Sasha Vujacic', 'Smush Parker')
# 3                    ('Andrew Bynum', 'Lamar Odom', 'Luke Walton', 'Sasha Vujacic', 'Smush Parker')
# 4                    ('Andrew Bynum', 'Lamar Odom', 'Luke Walton', 'Sasha Vujacic', 'Smush Parker')
# ...                                                                                             ...
# 1184555  ('Amir Johnson', 'DeMar DeRozan', 'Greivis Vasquez', 'Patrick Patterson', 'Terrence Ross')
# 1184556  ('Amir Johnson', 'DeMar DeRozan', 'Greivis Vasquez', 'Patrick Patterson', 'Terrence Ross')
# 1184557  ('Amir Johnson', 'DeMar DeRozan', 'Greivis Vasquez', 'Patrick Patterson', 'Terrence Ross')
# 1184558  ('Amir Johnson', 'DeMar DeRozan', 'Greivis Vasquez', 'Patrick Patterson', 'Terrence Ross')
# 1184559  ('Amir Johnson', 'DeMar DeRozan', 'Greivis Vasquez', 'Patrick Patterson', 'Terrence Ross')
#
#                                                                                    away_lineup  \
# 0                     ('Boris Diaw', 'Kurt Thomas', 'Raja Bell', 'Shawn Marion', 'Steve Nash')
# 1                     ('Boris Diaw', 'Kurt Thomas', 'Raja Bell', 'Shawn Marion', 'Steve Nash')
# 2                     ('Boris Diaw', 'Kurt Thomas', 'Raja Bell', 'Shawn Marion', 'Steve Nash')
# 3                     ('Boris Diaw', 'Kurt Thomas', 'Raja Bell', 'Shawn Marion', 'Steve Nash')
# 4                     ('Boris Diaw', 'Kurt Thomas', 'Raja Bell', 'Shawn Marion', 'Steve Nash')
# ...                                                                                        ...
# 1184555  ('Bismack Biyombo', 'Brian Roberts', 'Jeffery Taylor', 'Noah Vonleh', 'Troy Daniels')
# 1184556  ('Bismack Biyombo', 'Brian Roberts', 'Jeffery Taylor', 'Noah Vonleh', 'Troy Daniels')
# 1184557  ('Bismack Biyombo', 'Brian Roberts', 'Jeffery Taylor', 'Noah Vonleh', 'Troy Daniels')
# 1184558  ('Bismack Biyombo', 'Brian Roberts', 'Jeffery Taylor', 'Noah Vonleh', 'Troy Daniels')
# 1184559  ('Bismack Biyombo', 'Brian Roberts', 'Jeffery Taylor', 'Noah Vonleh', 'Troy Daniels')
#
#          duration  away_lineup_encoded  missing_position     missing_player  \
# 0             6.0             1.123045                 0       Andrew Bynum
# 1             6.0             1.123045                 1         Lamar Odom
# 2             6.0             1.123045                 2        Luke Walton
# 3             6.0             1.123045                 3      Sasha Vujacic
# 4             6.0             1.123045                 4       Smush Parker
# ...           ...                  ...               ...                ...
# 1184555       2.0             1.018073                 0       Amir Johnson
# 1184556       2.0             1.018073                 1      DeMar DeRozan
# 1184557       2.0             1.018073                 2    Greivis Vasquez
# 1184558       2.0             1.018073                 3  Patrick Patterson
# 1184559       2.0             1.018073                 4      Terrence Ross
#
#          home_lineup_avg  away_lineup_avg
# 0              -0.107619         1.317596
# 1              -0.107889         1.317596
# 2              -0.107863         1.317596
# 3              -0.135275         1.317596
# 4              -0.107330         1.317596
# ...                  ...              ...
# 1184555        -0.138642         0.975338
# 1184556        -0.150912         0.975338
# 1184557        -0.136270         0.975338
# 1184558        -0.138356         0.975338
# 1184559        -0.149974         0.975338
#
# [1184560 rows x 24 columns]

# %%
df_encoded
# Out:
#                 game  season home_team away_team  starting_min    home_0  \
# 0       200610310LAL    2007       LAL       PHO             0 -0.255631
# 1       200610310LAL    2007       LAL       PHO             6 -0.255631
# 2       200610310LAL    2007       LAL       PHO             8 -0.255631
# 3       200610310LAL    2007       LAL       PHO            10 -0.255631
# 4       200610310LAL    2007       LAL       PHO            11 -0.255631
# ...              ...     ...       ...       ...           ...       ...
# 215481  201504150TOR    2015       TOR       CHA            25 -0.255631
# 215482  201504150TOR    2015       TOR       CHA            35 -0.255631
# 215483  201504150TOR    2015       TOR       CHA            37 -0.255631
# 215484  201504150TOR    2015       TOR       CHA            45 -0.255631
# 215485  201504150TOR    2015       TOR       CHA            46 -0.255631
#
#           home_1    home_2    home_3    home_4    away_0    away_1    away_2  \
# 0      -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631
# 1      -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631
# 2      -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631
# 3      -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631
# 4      -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631
# ...          ...       ...       ...       ...       ...       ...       ...
# 215481 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631
# 215482 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631
# 215483 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631
# 215484 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631
# 215485 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631 -0.255631
#
#           away_3    away_4  outcome  \
# 0      -0.255631 -0.255631       -1
# 1      -0.255631 -0.255631       -1
# 2      -0.255631 -0.255631        1
# 3      -0.255631 -0.255631        1
# 4      -0.255631 -0.255631       -1
# ...          ...       ...      ...
# 215481 -0.255631 -0.255631        1
# 215482 -0.255631 -0.255631        1
# 215483 -0.255631 -0.255631       -1
# 215484 -0.255631 -0.255631       -1
# 215485 -0.255631 -0.255631       -1
#
#                                                                                   home_lineup  \
# 0                        (Andrew Bynum, Lamar Odom, Luke Walton, Sasha Vujacic, Smush Parker)
# 1                        (Andrew Bynum, Lamar Odom, Luke Walton, Sasha Vujacic, Smush Parker)
# 2                        (Lamar Odom, Luke Walton, Maurice Evans, Ronny Turiaf, Smush Parker)
# 3                        (Lamar Odom, Luke Walton, Maurice Evans, Ronny Turiaf, Smush Parker)
# 4               (Luke Walton, Maurice Evans, Ronny Turiaf, Smush Parker, Vladimir Radmanovic)
# ...                                                                                       ...
# 215481        (DeMar DeRozan, Jonas Valanciunas, Kyle Lowry, Terrence Ross, Tyler Hansbrough)
# 215482  (DeMar DeRozan, Greivis Vasquez, Jonas Valanciunas, Patrick Patterson, Terrence Ross)
# 215483          (Amir Johnson, Greivis Vasquez, James Johnson, Kyle Lowry, Patrick Patterson)
# 215484          (Amir Johnson, Greivis Vasquez, Kyle Lowry, Patrick Patterson, Terrence Ross)
# 215485       (Amir Johnson, DeMar DeRozan, Greivis Vasquez, Patrick Patterson, Terrence Ross)
#
#                                                                                away_lineup  \
# 0                           (Boris Diaw, Kurt Thomas, Raja Bell, Shawn Marion, Steve Nash)
# 1                (Amar'e Stoudemire, Leandro Barbosa, Raja Bell, Shawn Marion, Steve Nash)
# 2                (Amar'e Stoudemire, Leandro Barbosa, Raja Bell, Shawn Marion, Steve Nash)
# 3                    (Boris Diaw, James Jones, Kurt Thomas, Leandro Barbosa, Marcus Banks)
# 4                    (Boris Diaw, James Jones, Kurt Thomas, Leandro Barbosa, Marcus Banks)
# ...                                                                                    ...
# 215481  (Bismack Biyombo, Gerald Henderson, Jeffery Taylor, Kemba Walker, Marvin Williams)
# 215482        (Bismack Biyombo, Gerald Henderson, Kemba Walker, Noah Vonleh, Troy Daniels)
# 215483           (Brian Roberts, Jason Maxiell, Jeffery Taylor, Noah Vonleh, Troy Daniels)
# 215484         (Bismack Biyombo, Brian Roberts, Jeffery Taylor, Noah Vonleh, Troy Daniels)
# 215485         (Bismack Biyombo, Brian Roberts, Jeffery Taylor, Noah Vonleh, Troy Daniels)
#
#         duration  away_lineup_encoded
# 0            6.0            -0.255631
# 1            2.0            -0.255631
# 2            2.0            -0.255631
# 3            1.0            -0.255631
# 4            1.0            -0.255631
# ...          ...                  ...
# 215481      10.0            -0.255631
# 215482       2.0            -0.255631
# 215483       8.0            -0.255631
# 215484       1.0            -0.255631
# 215485       2.0            -0.255631
#
# [236912 rows x 20 columns]

# %%
X_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 X_train
#
# NameError: name 'X_train' is not defined

# %%
from sklearn.utils import resample

# Separate majority and minority classes
df_majority = df_train[df_train['outcome'] == -1]
df_minority = df_train[df_train['outcome'] == 1]

# Downsample majority class
df_majority_downsampled = resample(df_majority, 
                                   replace=False,    # Sample without replacement
                                   n_samples=len(df_minority),  # Match minority count
                                   random_state=42)

# Combine downsampled majority and original minority class
df_train_balanced = pd.concat([df_majority_downsampled, df_minority])

# Shuffle the dataset
df_train_balanced = df_train_balanced.sample(frac=1, random_state=42).reset_index(drop=True)

# Check new balance
print(df_train_balanced['outcome'].value_counts())
# Out:
# outcome
# -1    440875
#  1    440875
# Name: count, dtype: int64

# %%
# ===========================================================================================================================================
# STEP 6: Reduce Training Set by 80% (due to limitations of the machine that this model is being trained on)
# ===========================================================================================================================================
df_train_balanced = df_train_balanced.sample(frac=0.2, random_state=42).reset_index(drop=True)
df_train_balanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176350 entries, 0 to 176349
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   game                 176350 non-null  object
#  1   season               176350 non-null  int64
#  2   home_team            176350 non-null  object
#  3   away_team            176350 non-null  object
#  4   starting_min         176350 non-null  int64
#  5   home_0               141192 non-null  float64
#  6   home_1               141010 non-null  float64
#  7   home_2               140957 non-null  float64
#  8   home_3               140989 non-null  float64
#  9   home_4               141252 non-null  float64
#  10  away_0               176350 non-null  float64
#  11  away_1               176350 non-null  float64
#  12  away_2               176350 non-null  float64
#  13  away_3               176350 non-null  float64
#  14  away_4               176350 non-null  float64
#  15  outcome              176350 non-null  int64
#  16  home_lineup          176350 non-null  object
#  17  away_lineup          176350 non-null  object
#  18  duration             176350 non-null  float64
#  19  away_lineup_encoded  176350 non-null  float64
#  20  missing_position     176350 non-null  int64
#  21  missing_player       176350 non-null  object
#  22  home_lineup_avg      176350 non-null  float64
#  23  away_lineup_avg      176350 non-null  float64
# dtypes: float64(14), int64(4), object(6)
# memory usage: 32.3+ MB

# %%
# =============================================================================
# STEP 8: Split Data for Training
# =============================================================================
feature_cols = ['season', 'starting_min', 'home_team', 'away_team', 
                
                'home_0', 'home_1', 'home_2', 'home_3', 'home_4', 'away_0', 'away_1', 'away_2', 'away_3', 'away_4', 'outcome',]

X = df_train_balanced[feature_cols]
y = df_train_balanced['missing_player']

categorical_cols = ['season', 'home_team', 'away_team', 'outcome']
X = pd.get_dummies(X, columns=categorical_cols, drop_first=True)

# =============================================================================
# STEP 9: Encode the Target Variable
# =============================================================================
le = LabelEncoder()
y_encoded = le.fit_transform(y)
print("Target Classes:", le.classes_)

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.1, random_state=42)
# Out:
# Target Classes: ['A.J. Price' 'Aaron Brooks' 'Aaron Gordon' 'Aaron Gray' 'Aaron McKie'
#  'Aaron Williams' 'Acie Law' 'Adam Morrison' 'Adonal Foyle'
#  'Adonis Thomas' 'Adreian Payne' 'Adrian Griffin' 'Al Harrington'
#  'Al Horford' 'Al Jefferson' 'Al Thornton' 'Al-Farouq Aminu'
#  'Alan Anderson' 'Alan Henderson' 'Alando Tucker' 'Alec Burks'
#  'Alex Acker' 'Alex Len' 'Alexander Johnson' 'Alexey Shved'
#  'Alexis Ajinca' 'Allan Ray' 'Allen Crabbe' 'Allen Iverson' 'Alonzo Gee'
#  'Alonzo Mourning' 'Alvin Williams' "Amar'e Stoudemire" 'Amir Johnson'
#  'Anderson Varejao' 'Andray Blatche' 'Andre Barrett' 'Andre Brown'
#  'Andre Drummond' 'Andre Emmett' 'Andre Iguodala' 'Andre Miller'
#  'Andre Owens' 'Andre Roberson' 'Andrea Bargnani' 'Andrei Kirilenko'
#  'Andres Nocioni' 'Andrew Bogut' 'Andrew Bynum' 'Andrew Goudelock'
#  'Andrew Nicholson' 'Andrew Wiggins' 'Andris Biedrins' 'Andy Rautins'
#  'Anfernee Hardaway' 'Antawn Jamison' 'Anthony Bennett' 'Anthony Carter'
#  'Anthony Davis' 'Anthony Johnson' 'Anthony Morrow' 'Anthony Parker'
#  'Anthony Randolph' 'Anthony Roberson' 'Anthony Tolliver' 'Antoine Walker'
#  'Antoine Wright' 'Antonio Daniels' 'Antonio McDyess' 'Archie Goodwin'
#  'Arinze Onuaku' 'Armon Johnson' 'Arnett Moultrie' 'Aron Baynes'
#  'Arron Afflalo' 'Austin Croshere' 'Austin Daye' 'Austin Rivers'
#  'Avery Bradley' 'Awvee Storey' 'Baron Davis' 'Ben Gordon'
#  'Ben Hansbrough' 'Ben McLemore' 'Ben Uzoh' 'Ben Wallace' 'Beno Udrih'
#  'Bernard James' 'Bernard Robinson' 'Billy Thomas' 'Bismack Biyombo'
#  'Blake Ahearn' 'Blake Griffin' 'Bo Outlaw' 'Bobby Brown' 'Bobby Jackson'
#  'Bobby Jones' 'Bobby Simmons' 'Bojan Bogdanovic' 'Bonzi Wells'
#  'Boris Diaw' 'Bostjan Nachbar' 'Bracey Wright' 'Brad Miller'
#  'Bradley Beal' 'Brandan Wright' 'Brandon Bass' 'Brandon Davies'
#  'Brandon Jennings' 'Brandon Knight' 'Brandon Roy' 'Brandon Rush'
#  'Brendan Haywood' 'Brent Barry' 'Brevin Knight' 'Brian Cardinal'
#  'Brian Cook' 'Brian Roberts' 'Brian Scalabrine' 'Brian Skinner'
#  'Brook Lopez' 'Bruce Bowen' 'Bryce Cotton' 'Byron Mullens' 'C.J. Miles'
#  'C.J. Watson' 'CJ McCollum' 'Calvin Booth' 'Cameron Bairstow'
#  'Carl Landry' 'Carldell Johnson' 'Carlos Arroyo' 'Carlos Boozer'
#  'Carlos Delfino' 'Carmelo Anthony' 'Caron Butler' 'Carrick Felix'
#  'Cartier Martin' 'Casey Jacobsen' 'Casper Ware' 'Cedric Bozeman'
#  'Cedric Jackson' 'Cedric Simmons' 'Chandler Parsons' 'Channing Frye'
#  'Charles Jenkins' 'Charlie Bell' 'Charlie Villanueva' 'Chase Budinger'
#  'Chauncey Billups' 'Cheikh Samb' 'Chris Andersen' 'Chris Babb'
#  'Chris Bosh' 'Chris Copeland' 'Chris Douglas-Roberts' 'Chris Duhon'
#  'Chris Hunter' 'Chris Johnson' 'Chris Kaman' 'Chris Mihm' 'Chris Paul'
#  'Chris Quinn' 'Chris Richard' 'Chris Singleton' 'Chris Webber'
#  'Chris Wilcox' 'Chris Wright' 'Christian Eyenga' 'Chuck Hayes'
#  'Chucky Atkins' 'Cleanthony Early' 'Clifford Robinson' 'Clint Capela'
#  'Coby Karl' 'Cody Zeller' 'Cole Aldrich' 'Corey Brewer' 'Corey Maggette'
#  'Corliss Williamson' 'Cory Higgins' 'Cory Jefferson' 'Cory Joseph'
#  'Courtney Fortson' 'Courtney Lee' 'Courtney Sims' 'Craig Smith'
#  'Cuttino Mobley' 'D.J. Augustin' 'D.J. Kennedy' 'D.J. Stephens'
#  'D.J. Strawberry' 'D.J. White' 'DaJuan Summers' 'Daequan Cook'
#  'Dahntay Jones' 'Dajuan Wagner' 'Dale Davis' 'Damian Lillard'
#  'Damien Wilkins' 'Damion James' 'Damir Markota' 'Damjan Rudez'
#  'Damon Jones' 'Damon Stoudamire' 'Dan Dickau' 'Dan Gadzuric'
#  'Daniel Ewing' 'Daniel Gibson' 'Daniel Orton' 'Danilo Gallinari'
#  'Danny Fortson' 'Danny Granger' 'Danny Green' 'Dante Cunningham'
#  'Dante Exum' 'Darius Johnson-Odom' 'Darius Miles' 'Darius Miller'
#  'Darius Morris' 'Darius Songaila' 'Darius Washington' 'Darko Milicic'
#  'Darnell Jackson' 'Darrell Armstrong' 'Darrell Arthur' 'Darren Collison'
#  'Darrick Martin' 'David Andersen' 'David Harrison' 'David Lee'
#  'David Noel' 'David Wesley' 'David West' 'DeAndre Jordan'
#  'DeAndre Liggins' 'DeJuan Blair' 'DeMar DeRozan' 'DeMarcus Cousins'
#  'DeMarcus Nelson' 'DeMarre Carroll' 'DeQuan Jones' 'DeSagana Diop'
#  'DeShawn Stevenson' 'Dee Brown' 'Delonte West' 'Demetris Nichols'
#  'Dennis Schroder' 'DerMarr Johnson' 'Derek Anderson' 'Derek Fisher'
#  'Deron Williams' 'Derrick Brown' 'Derrick Caracter' 'Derrick Favors'
#  'Derrick Rose' 'Derrick Williams' 'Desmon Farmer' 'Desmond Mason'
#  'Devean George' 'Devin Brown' 'Devin Ebanks' 'Devin Harris'
#  'Devyn Marble' 'Dewayne Dedmon' 'Dexter Pittman' 'Diante Garrett'
#  'Didier Ilunga-Mbenga' 'Dijon Thompson' 'Dikembe Mutombo' 'Dion Waiters'
#  'Dionte Christmas' 'Dirk Nowitzki' 'Dominic McGuire' 'Dominique Jones'
#  'Donald Sloan' 'Donatas Motiejunas' 'Donell Taylor' 'Donte Greene'
#  'Dontell Jefferson' 'Donyell Marshall' 'Dorell Wright' 'Doron Lamb'
#  'Doug McDermott' 'Draymond Green' 'Drew Gooden' 'Drew Gordon'
#  'Dwayne Jones' 'Dwight Buycks' 'Dwight Howard' 'Dwight Powell'
#  'Dwyane Wade' "E'Twaun Moore" 'Earl Barron' 'Earl Boykins' 'Earl Clark'
#  'Earl Watson' 'Ed Davis' 'Eddie Gill' 'Eddie Griffin' 'Eddie House'
#  'Eddie Jones' 'Eddy Curry' 'Eduardo Najera' 'Edwin Ubiles' 'Ekpe Udoh'
#  'Elfrid Payton' 'Elias Harris' 'Elijah Millsap' 'Elliot Williams'
#  'Elton Brand' 'Emeka Okafor' 'Enes Kanter' 'Eric Bledsoe' 'Eric Gordon'
#  'Eric Maynor' 'Eric Piatkowski' 'Eric Snow' 'Eric Williams'
#  'Erick Dampier' 'Erick Green' 'Erik Murphy' 'Ersan Ilyasova'
#  'Esteban Batista' 'Etan Thomas' 'Eugene Jeter' 'Evan Fournier'
#  'Evan Turner' 'Fab Melo' 'Fabricio Oberto' 'Festus Ezeli'
#  'Francisco Elson' 'Francisco Garcia' 'Fred Jones' 'Furkan Aldemir'
#  'Gabe Pruitt' 'Gal Mekel' 'Garret Siler' 'Garrett Temple' 'Gary Forbes'
#  'Gary Harris' 'Gary Neal' 'Gary Payton' 'George Hill' 'Gerald Green'
#  'Gerald Henderson' 'Gerald Wallace' 'Giannis Antetokounmpo'
#  'Gilbert Arenas' 'Glen Davis' 'Glen Rice' 'Glenn Robinson' 'Goran Dragic'
#  'Gordan Giricek' 'Gordon Hayward' 'Gorgui Dieng' 'Grant Hill'
#  'Grant Jerrett' 'Greg Buckner' 'Greg Monroe' 'Greg Oden' 'Greg Smith'
#  'Greg Stiemsma' 'Greivis Vasquez' 'Gustavo Ayon' 'Hakim Warrick'
#  "Hamady N'Diaye" 'Hamed Haddadi' 'Harrison Barnes' 'Hasheem Thabeet'
#  'Hassan Adams' 'Hassan Whiteside' 'Hedo Turkoglu' 'Henry Sims'
#  'Henry Walker' 'Hilton Armstrong' 'Hollis Thompson' 'Ian Clark'
#  'Ian Mahinmi' 'Ike Diogu' 'Iman Shumpert' 'Ime Udoka' 'Ira Newble'
#  'Isaiah Canaan' 'Isaiah Thomas' 'Ish Smith' 'Ivan Johnson'
#  'Ivan McFarlin' 'J.J. Barea' 'J.J. Hickson' 'J.J. Redick' 'J.R. Giddens'
#  'J.R. Smith' 'JaJuan Johnson' 'JaKarr Sampson' 'JaMychal Green'
#  'JaVale McGee' 'Jabari Brown' 'Jabari Parker' 'Jack Cooley'
#  'Jackie Butler' 'Jacque Vaughn' 'Jae Crowder' 'Jake Tsakalidis'
#  'Jake Voskuhl' 'Jalen Rose' 'Jamaal Franklin' 'Jamaal Magloire'
#  'Jamaal Tinsley' 'Jamal Crawford' 'Jamal Sampson' 'Jamario Moon'
#  'Jameer Nelson' 'James Anderson' 'James Augustine' 'James Ennis'
#  'James Harden' 'James Johnson' 'James Jones' 'James Michael McAdoo'
#  'James Nunnally' 'James Posey' 'James Singleton' 'James Southerland'
#  'James White' 'James Young' 'Jan Vesely' 'Jannero Pargo'
#  'Jared Cunningham' 'Jared Dudley' 'Jared Jeffries' 'Jared Reiner'
#  'Jared Sullinger' 'Jarnell Stokes' 'Jarrett Jack' 'Jarron Collins'
#  'Jarvis Hayes' 'Jarvis Varnado' 'Jason Collins' 'Jason Hart'
#  'Jason Kapono' 'Jason Kidd' 'Jason Maxiell' 'Jason Richardson'
#  'Jason Smith' 'Jason Terry' 'Jason Thompson' 'Jason Williams'
#  'Javaris Crittenton' 'Jawad Williams' 'Jeff Adrien' 'Jeff Ayres'
#  'Jeff Foote' 'Jeff Foster' 'Jeff Green' 'Jeff McInnis' 'Jeff Teague'
#  'Jeff Withey' 'Jeffery Taylor' 'Jerami Grant' 'Jerel McNeal'
#  'Jeremy Evans' 'Jeremy Lamb' 'Jeremy Lin' 'Jeremy Pargo'
#  'Jeremy Richardson' 'Jeremy Tyler' "Jermaine O'Neal" 'Jermaine Taylor'
#  'Jermareo Davidson' 'Jerome Dyson' 'Jerome James' 'Jerome Jordan'
#  'Jerry Smith' 'Jerry Stackhouse' 'Jerryd Bayless' 'Jimmer Fredette'
#  'Jimmy Butler' 'Joakim Noah' 'Jodie Meeks' 'Joe Alexander' 'Joe Crawford'
#  'Joe Harris' 'Joe Ingles' 'Joe Johnson' 'Joe Smith' 'Joel Anthony'
#  'Joel Freeland' 'Joel Przybilla' 'Joey Dorsey' 'Joey Graham'
#  'Joffrey Lauvergne' 'Johan Petro' 'John Henson' 'John Jenkins'
#  'John Lucas III' 'John Salmons' 'John Wall' "Johnny O'Bryant"
#  'Jon Brockman' 'Jon Leuer' 'Jonas Jerebko' 'Jonas Valanciunas'
#  'Jonathan Bender' 'Jonny Flynn' 'Jordan Adams' 'Jordan Clarkson'
#  'Jordan Crawford' 'Jordan Farmar' 'Jordan Hamilton' 'Jordan Hill'
#  'Jordan Williams' 'Jorge Garbajosa' 'Jorge Gutierrez' 'Jose Calderon'
#  'Josh Akognon' 'Josh Boone' 'Josh Childress' 'Josh Davis'
#  'Josh Harrellson' 'Josh Howard' 'Josh McRoberts' 'Josh Powell'
#  'Josh Selby' 'Josh Smith' 'Jrue Holiday' 'Juan Carlos Navarro'
#  'Juan Dixon' 'Julian Wright' 'Julius Randle' 'Julyan Stone'
#  'Jumaine Jones' 'Junior Harrington' 'Justin Dentmon' 'Justin Hamilton'
#  'Justin Harper' 'Justin Holiday' 'Justin Reed' 'Justin Williams'
#  'Jusuf Nurkic' 'Juwan Howard' 'K.J. McDaniels' 'Kareem Rush'
#  'Kasib Powell' 'Kawhi Leonard' 'Keith Bogans' 'Keith McLeod'
#  'Kelenna Azubuike' 'Kelly Olynyk' 'Kelvin Cato' 'Kemba Walker'
#  'Kendall Marshall' 'Kendrick Perkins' 'Kenneth Faried' 'Kenny Thomas'
#  'Kent Bazemore' 'Kentavious Caldwell-Pope' 'Kenyon Martin' 'Kevin Durant'
#  'Kevin Garnett' 'Kevin Jones' 'Kevin Love' 'Kevin Martin' 'Kevin Ollie'
#  'Kevin Seraphin' 'Kevinn Pinkney' 'Keyon Dooling' 'Khris Middleton'
#  'Kim English' 'Kirk Hinrich' 'Kirk Snyder' 'Klay Thompson' 'Kobe Bryant'
#  'Kosta Koufos' 'Kostas Papanikolaou' 'Kris Humphries' 'Kris Joseph'
#  'Kurt Thomas' 'Kwame Brown' 'Kyle Anderson' 'Kyle Korver' 'Kyle Lowry'
#  "Kyle O'Quinn" 'Kyle Singler' 'Kyle Weaver' 'Kyrie Irving'
#  'Kyrylo Fesenko' 'LaMarcus Aldridge' 'Lamar Odom' 'Lance Stephenson'
#  'Lance Thomas' 'Landry Fields' 'Langston Galloway' 'Larry Drew'
#  'Larry Hughes' 'Larry Owens' 'Larry Sanders' 'Lavoy Allen'
#  'Lawrence Roberts' 'Lazar Hayward' 'LeBron James' 'Leandro Barbosa'
#  'Leon Powe' 'Lester Hudson' 'Linas Kleiza' 'Lindsey Hunter'
#  'Linton Johnson' 'Lorenzen Wright' 'Lorenzo Brown' 'Lou Amundson'
#  'Lou Williams' 'Luc Mbah a Moute' 'Luigi Datome' 'Luis Scola'
#  'Luke Babbitt' 'Luke Harangody' 'Luke Jackson' 'Luke Ridnour'
#  'Luke Schenscher' 'Luke Walton' 'Luke Zeller' 'Luol Deng' 'Luther Head'
#  'Lynn Greer' 'Maalik Wayns' 'Maceo Baston' 'Malcolm Lee' 'Malcolm Thomas'
#  'Malik Allen' 'Malik Hairston' 'Malik Rose' 'Manny Harris'
#  'Manu Ginobili' 'MarShon Brooks' 'Marc Gasol' 'Marc Jackson'
#  'Marcin Gortat' 'Marco Belinelli' 'Marcus Banks' 'Marcus Camby'
#  'Marcus Landry' 'Marcus Morris' 'Marcus Smart' 'Marcus Thornton'
#  'Marcus Vinicius' 'Marcus Williams' 'Mardy Collins' 'Mario Chalmers'
#  'Mario West' 'Mark Blount' 'Mark Madsen' 'Markel Brown' 'Markieff Morris'
#  'Marko Jaric' 'Marquis Daniels' 'Marquis Teague' 'Marreese Speights'
#  'Martell Webster' 'Marvin Williams' 'Mason Plumlee' 'Matt Barnes'
#  'Matt Bonner' 'Matt Carroll' 'Matt Freije' 'Matt Harpring'
#  'Matthew Dellavedova' 'Maurice Ager' 'Maurice Evans' 'Maurice Harkless'
#  'Maurice Taylor' 'Mehmet Okur' 'Melvin Ely' 'Metta World Peace'
#  'Meyers Leonard' 'Michael Beasley' 'Michael Carter-Williams'
#  'Michael Doleac' 'Michael Finley' 'Michael Kidd-Gilchrist'
#  'Michael Olowokandi' 'Michael Redd' 'Michael Ruffin' 'Mickael Gelabale'
#  'Mickael Pietrus' 'Mickell Gladness' 'Mike Bibby' 'Mike Conley'
#  'Mike Dunleavy' 'Mike Hall' 'Mike Harris' 'Mike James' 'Mike Miller'
#  'Mike Muscala' 'Mike Scott' 'Mike Sweetney' 'Mike Taylor' 'Mike Wilks'
#  'Mikki Moore' 'Miles Plumlee' 'Miroslav Raduljica' 'Mirza Teletovic'
#  'Mitch McGary' 'Mo Williams' 'Monta Ellis' 'Morris Almond'
#  'Morris Peterson' 'Mouhamed Sene' 'Mustafa Shakur' 'Mychel Thompson'
#  'Nando De Colo' 'Nate Robinson' 'Nate Wolters' 'Nathan Jawai'
#  'Nazr Mohammed' 'Nemanja Nedovic' 'Nenad Krstic' 'Nene Hilario'
#  'Nerlens Noel' 'Nick Calathes' 'Nick Collison' 'Nick Fazekas'
#  'Nick Johnson' 'Nick Young' 'Nicolas Batum' 'Nik Stauskas'
#  'Nikola Mirotic' 'Nikola Pekovic' 'Nikola Vucevic' 'Noah Vonleh'
#  'Nolan Smith' 'Norris Cole' 'O.J. Mayo' 'Ognjen Kuzmic'
#  'Oleksiy Pecherov' 'Oliver Lafayette' 'Omer Asik' 'Omri Casspi'
#  'Orien Greene' 'Orlando Johnson' 'Othella Harrington' 'Othello Hunter'
#  'Othyus Jeffers' 'Otto Porter' 'P.J. Brown' 'P.J. Hairston' 'P.J. Tucker'
#  'Pablo Prigioni' 'Pape Sow' 'Pat Burke' 'Pat Garrity' 'Patrick Beverley'
#  'Patrick Christopher' "Patrick O'Bryant" 'Patrick Patterson'
#  'Patty Mills' 'Pau Gasol' 'Paul Davis' 'Paul George' 'Paul Millsap'
#  'Paul Pierce' 'Peja Stojakovic' 'Pero Antic' 'Perry Jones' 'Peyton Siva'
#  'Phil Pressey' 'Pops Mensah-Bonsu' 'Primoz Brezec' 'Quentin Richardson'
#  'Quincy Acy' 'Quincy Douby' 'Quincy Miller' 'Quincy Pondexter'
#  'Quinton Ross' 'Raef LaFrentz' 'Rafael Araujo' 'Rafer Alston' 'Raja Bell'
#  'Rajon Rondo' 'Ramon Sessions' 'Randolph Morris' 'Randy Foye'
#  'Rashad McCants' 'Rashard Lewis' 'Rasheed Wallace' 'Rasho Nesterovic'
#  'Rasual Butler' 'Rawle Marshall' 'Ray Allen' 'Ray McCallum'
#  'Raymond Felton' 'Reggie Bullock' 'Reggie Evans' 'Reggie Jackson'
#  'Reggie Williams' 'Renaldo Balkman' 'Richard Hamilton'
#  'Richard Jefferson' 'Richie Frahm' 'Ricky Davis' 'Ricky Ledo'
#  'Ricky Rubio' 'Rob Kurz' 'Robbie Hummel' 'Robert Covington' 'Robert Hite'
#  'Robert Horry' 'Robert Sacre' 'Robert Swift' 'Robin Lopez'
#  'Rodney Carney' 'Rodney Hood' 'Rodney Stuckey' 'Rodrigue Beaubois'
#  'Roger Mason' 'Roger Powell' 'Roko Ukic' 'Ronald Murray' 'Ronnie Brewer'
#  'Ronnie Price' 'Ronny Turiaf' 'Roy Hibbert' 'Royal Ivey'
#  'Ruben Patterson' 'Rudy Fernandez' 'Rudy Gay' 'Rudy Gobert'
#  'Russell Westbrook' 'Ryan Anderson' 'Ryan Bowen' 'Ryan Gomes'
#  'Ryan Hollins' 'Ryan Kelly' 'Salim Stoudamire' 'Sam Cassell' 'Sam Young'
#  'Samardo Samuels' 'Samuel Dalembert' 'Sarunas Jasikevicius'
#  'Sasha Pavlovic' 'Sasha Vujacic' 'Scot Pollard' 'Scott Padgett'
#  'Sean Kilpatrick' 'Sean Marks' 'Sean May' 'Sean Singletary'
#  'Sean Williams' 'Sebastian Telfair' 'Semih Erden' 'Serge Ibaka'
#  'Sergey Karasev' 'Sergio Rodriguez' 'Seth Curry' 'Shabazz Muhammad'
#  'Shabazz Napier' 'Shammond Williams' 'Shane Battier' 'Shane Larkin'
#  'Shannon Brown' "Shaquille O'Neal" 'Shareef Abdur-Rahim'
#  'Shaun Livingston' 'Shavlik Randolph' 'Shawn Marion' 'Shawne Williams'
#  'Shayne Whittington' 'Shelden Williams' 'Shelvin Mack' 'Sherron Collins'
#  'Smush Parker' 'Solomon Alabi' 'Solomon Hill' 'Solomon Jones'
#  'Sonny Weems' 'Speedy Claxton' 'Spencer Dinwiddie' 'Spencer Hawes'
#  'Stanislav Medvedenko' 'Stephane Lasme' 'Stephen Curry' 'Stephen Graham'
#  'Stephen Jackson' 'Stephon Marbury' 'Steve Blake' 'Steve Francis'
#  'Steve Nash' 'Steve Novak' 'Steven Adams' 'Steven Hill' 'Steven Hunter'
#  'Steven Smith' 'Stromile Swift' 'Sundiata Gaines' 'T.J. Ford'
#  'T.J. Warren' 'Taj Gibson' 'Tarence Kinsey' 'Tarik Black'
#  'Tayshaun Prince' 'Terrel Harris' 'Terrence Jones' 'Terrence Ross'
#  'Terrence Williams' 'Thabo Sefolosha' 'Thaddeus Young' 'Theo Ratliff'
#  'Thomas Gardner' 'Thomas Robinson' 'Tiago Splitter' 'Tim Duncan'
#  'Tim Frazier' 'Tim Hardaway' 'Tim Ohlbrecht' 'Tim Thomas'
#  'Timofey Mozgov' 'Tobias Harris' 'Toney Douglas' 'Tony Allen'
#  'Tony Battie' 'Tony Mitchell' 'Tony Parker' 'Tony Snell' 'Tony Wroten'
#  'Tornike Shengelia' "Toure' Murry" 'Tracy McGrady' 'Travis Diener'
#  'Travis Leslie' 'Travis Outlaw' 'Travis Wear' 'Trenton Hassell'
#  'Trevor Ariza' 'Trevor Booker' 'Trey Burke' 'Trey Johnson'
#  'Trey Thompkins' 'Tristan Thompson' 'Troy Daniels' 'Troy Hudson'
#  'Troy Murphy' 'Ty Lawson' 'Tyler Ennis' 'Tyler Hansbrough'
#  'Tyler Honeycutt' 'Tyler Johnson' 'Tyler Zeller' 'Tyreke Evans'
#  'Tyronn Lue' 'Tyrus Thomas' 'Tyshawn Taylor' 'Tyson Chandler'
#  'Udonis Haslem' 'Vassilis Spanoulis' 'Vernon Macklin'
#  'Viacheslav Kravtsov' 'Victor Claver' 'Victor Oladipo' 'Viktor Khryapa'
#  'Vince Carter' 'Vitor Faverani' 'Vladimir Radmanovic' 'Von Wafer'
#  'Walker Russell' 'Wally Szczerbiak' 'Walter Herrmann' 'Wayne Ellington'
#  'Wayne Simien' 'Wesley Johnson' 'Wesley Matthews' 'Will Barton'
#  'Will Blalock' 'Will Bynum' 'Will Cherry' 'Will Conroy' 'Will Solomon'
#  'Willie Green' 'Willie Warren' 'Wilson Chandler' 'Xavier Henry'
#  'Yakhouba Diawara' 'Yao Ming' 'Yaroslav Korolev' 'Yi Jianlian'
#  'Zabian Dowdell' 'Zach LaVine' 'Zach Randolph' 'Zaza Pachulia'
#  'Zydrunas Ilgauskas']

# %%
rf_model = RandomForestClassifier(
    n_estimators=100,  
    max_depth=15, 
    max_features='sqrt',  
    min_samples_split=5,  
    min_samples_leaf=2,  
    random_state=42,
    n_jobs=-1,  # Use all CPU cores for faster training
    verbose=1
)
rf_model.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    6.0s finished
# RandomForestClassifier(max_depth=15, min_samples_leaf=2, min_samples_split=5,
#                        n_jobs=-1, random_state=42, verbose=1)

# %%
def filter_predictions_by_team_season(pred_probs, X_test, label_encoder):
    """
    Ensures that the predicted players are only from the correct team and season.
    """
    filtered_preds = []

    for i, probs in enumerate(pred_probs):
        season = X_test.iloc[i]['season']
        home_team = X_test.iloc[i]['home_team']

        # Get valid players for this team and season
        valid_players = team_player_dict.get((season, home_team), set())

        # Convert valid player names to their encoded values
        valid_player_labels = set(label_encoder.transform(list(valid_players)).tolist())

        # Sort predictions by probability
        sorted_indices = np.argsort(probs)[::-1]  # Descending order

        # Find the highest-ranked valid prediction
        for idx in sorted_indices:
            if idx in valid_player_labels:
                filtered_preds.append(idx)
                break
        else:
            # If no valid player is found, use a fallback (e.g., most common missing player)
            filtered_preds.append(-1)

    return np.array(filtered_preds)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 filtered_preds
#
# NameError: name 'filtered_preds' is not defined

# %%
# Save the model to a file named 'random_forest_model.pkl'
joblib.dump(rf_model, 'rf_model_final.pkl')
# Out:
# ['rf_model_final.pkl']

# %%
# Load the trained model
rf_model = joblib.load("rf_model_final.pkl")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Load the trained model
# ----> 2 rf_model = joblib.load("rf_model_final.pkl")
#
# File e:\Personal\GitHub\ML-NBALineupPrediction\.venv\lib\site-packages\joblib\numpy_pickle.py:658, in load(filename, mmap_mode)
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#     656                 return load_compatibility(fobj)
# --> 658             obj = _unpickle(fobj, filename, mmap_mode)
#     659 return obj
#
# File e:\Personal\GitHub\ML-NBALineupPrediction\.venv\lib\site-packages\joblib\numpy_pickle.py:577, in _unpickle(fobj, filename, mmap_mode)
#     575 obj = None
#     576 try:
# --> 577     obj = unpickler.load()
#     578     if unpickler.compat_mode:
#     579         warnings.warn("The file '%s' has been generated with a "
#     580                       "joblib version less than 0.10. "
#     581                       "Please regenerate this pickle file."
#     582                       % filename,
#     583                       DeprecationWarning, stacklevel=3)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\pickle.py:1213, in _Unpickler.load(self)
#    1211             raise EOFError
#    1212         assert isinstance(key, bytes_types)
# -> 1213         dispatch[key[0]](self)
#    1214 except _Stop as stopinst:
#    1215     return stopinst.value
#
# File e:\Personal\GitHub\ML-NBALineupPrediction\.venv\lib\site-packages\joblib\numpy_pickle.py:415, in NumpyUnpickler.load_build(self)
#     413 if isinstance(array_wrapper, NDArrayWrapper):
#     414     self.compat_mode = True
# --> 415 self.stack.append(array_wrapper.read(self))
#
# File e:\Personal\GitHub\ML-NBALineupPrediction\.venv\lib\site-packages\joblib\numpy_pickle.py:252, in NumpyArrayWrapper.read(self, unpickler)
#     250     array = self.read_mmap(unpickler)
#     251 else:
# --> 252     array = self.read_array(unpickler)
#     254 # Manage array subclass case
#     255 if (hasattr(array, '__array_prepare__') and
#     256     self.subclass not in (unpickler.np.ndarray,
#     257                           unpickler.np.memmap)):
#     258     # We need to reconstruct another subclass
#
# File e:\Personal\GitHub\ML-NBALineupPrediction\.venv\lib\site-packages\joblib\numpy_pickle.py:173, in NumpyArrayWrapper.read_array(self, unpickler)
#     163 # This is not a real file. We have to read it the
#     164 # memory-intensive way.
#     165 # crc32 module fails on reads greater than 2 ** 32 bytes,
#    (...)
#     168 # of the read. In non-chunked case count < max_read_count, so
#     169 # only one read is performed.
#     170 max_read_count = BUFFER_SIZE // min(BUFFER_SIZE,
#     171                                     self.dtype.itemsize)
# --> 173 array = unpickler.np.empty(count, dtype=self.dtype)
#     174 for i in range(0, count, max_read_count):
#     175     read_count = min(max_read_count, count - i)
#
# MemoryError: Unable to allocate 36.4 MiB for an array with shape (4771052,) and data type float64

# %%
# ----------------------------------------------------------------------------
# STEP 1: Load Test Data and Replace "?" with NaN
# ----------------------------------------------------------------------------
df_test = pd.read_csv("../data/NBA_test copy.csv")
df_test_labels = pd.read_csv("../data/NBA_test_labels.csv")

# Merge labels into test data (actual missing player names, if needed for evaluation)
df_test['missing_player'] = df_test_labels['removed_value']

# Replace team acronyms if needed
df_test["home_team"] = df_test["home_team"].replace(team_acronym_mapping)
df_test["away_team"] = df_test["away_team"].replace(team_acronym_mapping)

df_test['outcome'] = 1  # Required for feature alignment with training

# Replace "?" in player columns with NaN
df_test.replace("?", np.nan, inplace=True)

# ----------------------------------------------------------------------------
# STEP 2: Apply Player Mean Encoding (Handling 2016 Unseen Players)
# ----------------------------------------------------------------------------
def encode_player_test(row, col, mean_dict, team_col):
    """
    Looks up player encoding:
    1. Check (2016, team, player).
    2. If not found, check (2015, team, player).
    3. If still not found, use team avg encoding from 2015.
    4. If no team avg available, use overall fallback.
    """
    player = row[col]
    season = row['season']
    team = row[team_col]
    
    if pd.isna(player):  # Preserve NaN for missing players
        return np.nan

    # 1️⃣ Check player encoding for current season & team
    key = (season, team, player)
    if key in mean_dict:
        return mean_dict[key]

    # 2️⃣ Check player encoding from 2015 (if they moved teams)
    key_2015 = (2015, team, player)
    if key_2015 in mean_dict:
        return mean_dict[key_2015]

    # 3️⃣ Use team average encoding from 2015 if available
    if team in team_avg_encoding_away:
        return team_avg_encoding_away[team]

    # 4️⃣ If nothing found, fallback to overall average
    return overall_fallback

# Apply correct encoding for home players
for col in ['home_0', 'home_1', 'home_2', 'home_3', 'home_4']:
    df_test[col] = df_test.apply(lambda row: encode_player_test(row, col, mean_encoding_dict_home, 'home_team'), axis=1)

# Apply correct encoding for away players
for col in ['away_0', 'away_1', 'away_2', 'away_3', 'away_4']:
    df_test[col] = df_test.apply(lambda row: encode_player_test(row, col, mean_encoding_dict_away, 'away_team'), axis=1)

# ----------------------------------------------------------------------------
# STEP 3: Encode the Missing Player Using LabelEncoder
# ----------------------------------------------------------------------------
def encode_missing_player(player):
    """Encodes the missing player using the trained label encoder from training."""
    if pd.isna(player):
        return np.nan  # Preserve NaN values
    elif player in le.classes_:
        return le.transform([player])[0]  # Use existing label
    else:
        return -1  # Assign a special label for unseen players

df_test['missing_player_encoded'] = df_test['missing_player'].apply(encode_missing_player)

# ----------------------------------------------------------------------------
# STEP 4: Compute Away Lineup Encoding
# ----------------------------------------------------------------------------
def encode_away_lineup(row):
    """
    Compute the mean encoding for the away lineup.
    - If a player is missing in 2016, check 2015 data.
    - If still missing, use 2015 team mean encoding.
    - If no team data exists, use overall fallback.
    """
    encodings = []
    
    for col in ['away_0', 'away_1', 'away_2', 'away_3', 'away_4']:
        player = row[col]
        season = row['season']
        team = row['away_team']

        # 1️⃣ Check player encoding for 2016
        key = (season, team, player)
        if key in mean_encoding_dict_away:
            encodings.append(mean_encoding_dict_away[key])
            continue

        # 2️⃣ Check 2015 encoding
        key_2015 = (2015, team, player)
        if key_2015 in mean_encoding_dict_away:
            encodings.append(mean_encoding_dict_away[key_2015])
            continue

        # 3️⃣ Use 2015 team average encoding if available
        if team in team_avg_encoding_away:
            encodings.append(team_avg_encoding_away[team])
            continue

        # 4️⃣ Use overall fallback
        encodings.append(overall_fallback)
    
    return np.nanmean(encodings)  # Compute the final away lineup encoding

# Apply encoding function
df_test['away_lineup_encoded'] = df_test.apply(encode_away_lineup, axis=1)

# ----------------------------------------------------------------------------
# STEP 5: Compute Aggregate Features
# ----------------------------------------------------------------------------
df_test['home_lineup_avg'] = df_test[['home_0', 'home_1', 'home_2', 'home_3', 'home_4']].mean(axis=1, skipna=True)
df_test['away_lineup_avg'] = df_test[['away_0', 'away_1', 'away_2', 'away_3', 'away_4']].mean(axis=1, skipna=True)

# ----------------------------------------------------------------------------
# STEP 6: Apply One-Hot Encoding to Categorical Features
# ----------------------------------------------------------------------------
categorical_cols = ['season', 'home_team', 'away_team', 'outcome']
X_test_eval = df_test[['season', 'starting_min', 'home_team', 'away_team', 
                       'home_lineup_avg', 'away_lineup_avg', 'away_lineup_encoded',
                       'home_0', 'home_1', 'home_2', 'home_3', 'home_4', 
                       'away_0', 'away_1', 'away_2', 'away_3', 'away_4', 'outcome']]

# Apply one-hot encoding (aligning with training data)
X_test_eval = pd.get_dummies(X_test_eval, columns=categorical_cols, drop_first=True)

# Ensure columns match training data
missing_cols = set(X.columns) - set(X_test_eval.columns)
extra_cols = set(X_test_eval.columns) - set(X.columns)

# Add missing columns with zeros
for col in missing_cols:
    X_test_eval[col] = 0

# Drop extra columns
X_test_eval = X_test_eval[X.columns]

# Ensure test labels match the label-encoded format
y_test_eval = df_test['missing_player_encoded'].astype(int)

print("✅ Test Data Prepared Successfully! 2016 player encoding corrected.")
# Out:
# ✅ Test Data Prepared Successfully! 2016 player encoding corrected.

# %%
X_test_eval
# Out:
#      starting_min    home_0    home_1    home_2    home_3    home_4    away_0  \
# 0              18 -0.250878 -0.174603 -0.075000 -0.256497       NaN  1.282799
# 1              16 -0.164557       NaN -0.114815 -0.163671  0.023331  1.339869
# 2              39 -0.248804       NaN -0.029815 -0.179487 -0.020260  1.267159
# 3              21       NaN -0.135282 -0.214058 -0.182609 -0.178131  1.316352
# 4              19 -0.229630 -0.290821 -0.154173 -0.277551       NaN  1.283352
# ..            ...       ...       ...       ...       ...       ...       ...
# 995            20       NaN -0.137681 -0.233853  1.129307  1.129307  1.072671
# 996            21 -0.110507  1.095437       NaN -0.106383  1.095437  1.018073
# 997            13  1.134357       NaN -0.128713 -0.110473 -0.449275  1.014625
# 998            24 -0.099099 -0.129001       NaN -0.051410 -0.183355  1.144363
# 999            20 -0.197429  1.129307 -0.137681 -0.233853       NaN  1.124165
#
#        away_1    away_2    away_3    away_4  season_2008  season_2009  \
# 0    1.361179  1.341333  1.259325  1.388626        False        False
# 1    1.465726  1.261490  1.416723  1.429043        False        False
# 2    1.265161  1.248939  1.237654  1.238655        False        False
# 3    1.290878  1.278547  1.353086  1.259325        False        False
# 4    1.277124  1.214050  1.260579  1.212892        False        False
# ..        ...       ...       ...       ...          ...          ...
# 995  1.018073  0.972549  1.020325  1.018073        False        False
# 996  1.018073  0.972549  1.020325  1.018073        False        False
# 997  0.967742  1.014625  1.014625  1.014625        False        False
# 998  1.096998  1.144363  1.155131  1.103226        False        False
# 999  1.057903  1.052950  1.124165  1.124165        False        False
#
#      season_2010  season_2011  season_2012  season_2013  season_2014  \
# 0          False        False        False        False        False
# 1          False        False        False        False        False
# 2          False        False        False        False        False
# 3          False        False        False        False        False
# 4          False        False        False        False        False
# ..           ...          ...          ...          ...          ...
# 995        False        False        False        False        False
# 996        False        False        False        False        False
# 997        False        False        False        False        False
# 998        False        False        False        False        False
# 999        False        False        False        False        False
#
#      season_2015  home_team_BOS  home_team_BRK  home_team_CHA  home_team_CHI  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
# 2          False          False          False          False          False
# 3          False          False          False          False          False
# 4          False          False          False          False          False
# ..           ...            ...            ...            ...            ...
# 995        False          False           True          False          False
# 996        False          False          False          False          False
# 997        False          False          False          False          False
# 998        False          False          False          False          False
# 999        False          False           True          False          False
#
#      home_team_CLE  home_team_DAL  home_team_DEN  home_team_DET  \
# 0            False          False          False          False
# 1            False          False          False          False
# 2            False          False          False          False
# 3            False          False          False          False
# 4            False          False          False          False
# ..             ...            ...            ...            ...
# 995          False          False          False          False
# 996          False          False          False          False
# 997          False           True          False          False
# 998          False          False          False          False
# 999          False          False          False          False
#
#      home_team_GSW  home_team_HOU  home_team_IND  home_team_LAC  \
# 0            False          False           True          False
# 1            False           True          False          False
# 2            False          False          False          False
# 3            False          False          False          False
# 4            False          False          False          False
# ..             ...            ...            ...            ...
# 995          False          False          False          False
# 996          False          False          False          False
# 997          False          False          False          False
# 998          False          False          False          False
# 999          False          False          False          False
#
#      home_team_LAL  home_team_MEM  home_team_MIA  home_team_MIL  \
# 0            False          False          False          False
# 1            False          False          False          False
# 2            False          False          False          False
# 3            False          False          False          False
# 4            False           True          False          False
# ..             ...            ...            ...            ...
# 995          False          False          False          False
# 996          False          False          False          False
# 997          False          False          False          False
# 998          False          False          False          False
# 999          False          False          False          False
#
#      home_team_MIN  home_team_NOP  home_team_NYK  home_team_OKC  \
# 0            False          False          False          False
# 1            False          False          False          False
# 2            False          False          False          False
# 3             True          False          False          False
# 4            False          False          False          False
# ..             ...            ...            ...            ...
# 995          False          False          False          False
# 996          False          False          False          False
# 997          False          False          False          False
# 998          False           True          False          False
# 999          False          False          False          False
#
#      home_team_ORL  home_team_PHI  home_team_PHO  home_team_POR  \
# 0            False          False          False          False
# 1            False          False          False          False
# 2            False          False          False          False
# 3            False          False          False          False
# 4            False          False          False          False
# ..             ...            ...            ...            ...
# 995          False          False          False          False
# 996          False          False          False          False
# 997          False          False          False          False
# 998          False          False          False          False
# 999          False          False          False          False
#
#      home_team_SAC  home_team_SAS  home_team_TOR  home_team_UTA  \
# 0            False          False          False          False
# 1            False          False          False          False
# 2            False           True          False          False
# 3            False          False          False          False
# 4            False          False          False          False
# ..             ...            ...            ...            ...
# 995          False          False          False          False
# 996          False          False           True          False
# 997          False          False          False          False
# 998          False          False          False          False
# 999          False          False          False          False
#
#      home_team_WAS  away_team_BOS  away_team_BRK  away_team_CHA  \
# 0            False           True          False          False
# 1            False          False          False          False
# 2            False          False          False          False
# 3            False           True          False          False
# 4            False          False          False          False
# ..             ...            ...            ...            ...
# 995          False          False          False           True
# 996          False          False          False           True
# 997          False          False          False          False
# 998          False          False          False          False
# 999          False          False          False          False
#
#      away_team_CHI  away_team_CLE  away_team_DAL  away_team_DEN  \
# 0            False          False          False          False
# 1            False          False           True          False
# 2            False          False          False          False
# 3            False          False          False          False
# 4            False          False          False          False
# ..             ...            ...            ...            ...
# 995          False          False          False          False
# 996          False          False          False          False
# 997          False          False          False          False
# 998          False          False          False          False
# 999          False          False          False          False
#
#      away_team_DET  away_team_GSW  away_team_HOU  away_team_IND  \
# 0            False          False          False          False
# 1            False          False          False          False
# 2            False          False          False          False
# 3            False          False          False          False
# 4            False          False          False          False
# ..             ...            ...            ...            ...
# 995          False          False          False          False
# 996          False          False          False          False
# 997           True          False          False          False
# 998          False          False          False          False
# 999          False          False          False          False
#
#      away_team_LAC  away_team_LAL  away_team_MEM  away_team_MIA  \
# 0            False          False          False          False
# 1            False          False          False          False
# 2            False          False          False          False
# 3            False          False          False          False
# 4            False           True          False          False
# ..             ...            ...            ...            ...
# 995          False          False          False          False
# 996          False          False          False          False
# 997          False          False          False          False
# 998          False          False          False          False
# 999          False          False          False          False
#
#      away_team_MIL  away_team_MIN  away_team_NOP  away_team_NYK  \
# 0            False          False          False          False
# 1            False          False          False          False
# 2            False          False          False          False
# 3            False          False          False          False
# 4            False          False          False          False
# ..             ...            ...            ...            ...
# 995          False          False          False          False
# 996          False          False          False          False
# 997          False          False          False          False
# 998          False          False          False          False
# 999          False          False          False           True
#
#      away_team_OKC  away_team_ORL  away_team_PHI  away_team_PHO  \
# 0            False          False          False          False
# 1            False          False          False          False
# 2            False          False          False          False
# 3            False          False          False          False
# 4            False          False          False          False
# ..             ...            ...            ...            ...
# 995          False          False          False          False
# 996          False          False          False          False
# 997          False          False          False          False
# 998          False           True          False          False
# 999          False          False          False          False
#
#      away_team_POR  away_team_SAC  away_team_SAS  away_team_TOR  \
# 0            False          False          False          False
# 1            False          False          False          False
# 2             True          False          False          False
# 3            False          False          False          False
# 4            False          False          False          False
# ..             ...            ...            ...            ...
# 995          False          False          False          False
# 996          False          False          False          False
# 997          False          False          False          False
# 998          False          False          False          False
# 999          False          False          False          False
#
#      away_team_UTA  away_team_WAS  outcome_1
# 0            False          False          0
# 1            False          False          0
# 2            False          False          0
# 3            False          False          0
# 4            False          False          0
# ..             ...            ...        ...
# 995          False          False          0
# 996          False          False          0
# 997          False          False          0
# 998          False          False          0
# 999          False          False          0
#
# [1000 rows x 78 columns]

# %%
 #----------------------------------------------------------------------------
# STEP 6: Make Predictions and Evaluate Model
# ----------------------------------------------------------------------------
rf_predictions = rf_model.predict(X_test_eval)

# Compute accuracy
rf_accuracy = accuracy_score(y_test_eval.dropna(), rf_predictions)  # Drop NaNs to avoid errors

# Convert numeric predictions back to player names
y_pred_names = le.inverse_transform(rf_predictions)

# Generate classification report
unique_labels = np.unique(y_test_eval.dropna())  # Drop NaN values to avoid issues
target_names = [le.classes_[i] for i in unique_labels]

print(f"🎯 Random Forest Accuracy: {rf_accuracy:.4f}")
print("\n📊 Classification Report:")
print(classification_report(y_test_eval.dropna(), rf_predictions, labels=unique_labels, target_names=target_names))
# Out:
# [Parallel(n_jobs=16)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done  18 tasks      | elapsed:    0.0s
# 🎯 Random Forest Accuracy: 0.3990
#
# 📊 Classification Report:
#                          precision    recall  f1-score   support
#
#      Zydrunas Ilgauskas       0.00      0.00      0.00         8
#              A.J. Price       0.00      0.00      0.00         1
#            Aaron Brooks       0.50      1.00      0.67         2
#                Acie Law       0.00      0.00      0.00         1
#           Al Harrington       0.00      0.00      0.00         2
#              Al Horford       0.38      1.00      0.55         3
#            Al Jefferson       0.50      1.00      0.67         4
#         Al-Farouq Aminu       0.50      1.00      0.67         1
#           Alan Anderson       0.50      1.00      0.67         1
#              Alec Burks       0.00      0.00      0.00         1
#            Alexey Shved       0.00      0.00      0.00         1
#           Alexis Ajinca       0.00      0.00      0.00         1
#            Allen Crabbe       0.00      0.00      0.00         2
#           Allen Iverson       0.50      0.50      0.50         2
#       Amar'e Stoudemire       0.38      1.00      0.55         3
#            Amir Johnson       0.33      0.25      0.29         4
#        Anderson Varejao       0.40      1.00      0.57         2
#          Andray Blatche       0.00      0.00      0.00         1
#          Andre Drummond       0.67      1.00      0.80         2
#          Andre Iguodala       0.33      1.00      0.50         2
#            Andre Miller       0.67      0.40      0.50         5
#         Andrea Bargnani       0.00      0.00      0.00         3
#         Stephen Jackson       0.50      0.25      0.33         4
#         Stephon Marbury       0.00      0.00      0.00         2
#             Steve Blake       0.67      0.80      0.73         5
#           Steve Francis       0.00      0.00      0.00         1
#              Steve Nash       0.60      1.00      0.75         3
#             Steve Novak       1.00      0.33      0.50         3
#          Stromile Swift       0.00      0.00      0.00         1
#               T.J. Ford       1.00      1.00      1.00         1
#              Taj Gibson       0.00      0.00      0.00         2
#          Terrence Jones       1.00      0.50      0.67         2
#           Terrence Ross       0.00      0.00      0.00         1
#         Thabo Sefolosha       0.00      0.00      0.00         1
#          Thaddeus Young       0.33      1.00      0.50         4
#         Thomas Robinson       0.00      0.00      0.00         2
#          Tiago Splitter       0.00      0.00      0.00         1
#              Tim Duncan       0.29      0.50      0.36         4
#            Tim Hardaway       1.00      0.50      0.67         2
#              Tim Thomas       0.33      1.00      0.50         1
#          Timofey Mozgov       0.00      0.00      0.00         1
#           Tobias Harris       0.00      0.00      0.00         1
#           Toney Douglas       1.00      0.33      0.50         3
#              Tony Allen       0.25      0.20      0.22         5
#             Tony Parker       0.70      1.00      0.82         7
#              Tony Snell       0.00      0.00      0.00         2
#           Tracy McGrady       1.00      0.50      0.67         2
#           Travis Diener       0.00      0.00      0.00         1
#           Travis Outlaw       1.00      1.00      1.00         2
#         Trenton Hassell       0.00      0.00      0.00         1
#            Trevor Ariza       0.25      1.00      0.40         1
#              Trey Burke       1.00      1.00      1.00         1
#        Tristan Thompson       0.33      0.50      0.40         4
#             Troy Murphy       1.00      1.00      1.00         3
#               Ty Lawson       0.43      0.75      0.55         4
#             Tyler Ennis       0.00      0.00      0.00         1
#        Tyler Hansbrough       1.00      1.00      1.00         2
#            Tyler Zeller       0.00      0.00      0.00         2
#            Tyreke Evans       0.40      1.00      0.57         2
#            Tyrus Thomas       0.00      0.00      0.00         1
#          Tyson Chandler       0.60      1.00      0.75         3
#           Udonis Haslem       0.40      0.67      0.50         3
#          Victor Oladipo       1.00      1.00      1.00         2
#            Vince Carter       0.50      0.67      0.57         3
#               Von Wafer       0.00      0.00      0.00         1
#         Wayne Ellington       1.00      0.33      0.50         3
#          Wesley Johnson       0.00      0.00      0.00         1
#         Wesley Matthews       0.50      1.00      0.67         1
#             Will Barton       0.00      0.00      0.00         1
#              Will Bynum       1.00      0.50      0.67         2
#            Willie Green       1.00      1.00      1.00         2
#         Wilson Chandler       0.45      0.83      0.59         6
#        Yakhouba Diawara       0.00      0.00      0.00         1
#           Zach Randolph       0.78      1.00      0.88         7
#           Zaza Pachulia       0.40      1.00      0.57         4
#      Zydrunas Ilgauskas       0.60      1.00      0.75         3
#
#               micro avg       0.42      0.40      0.41      1000
#               macro avg       0.30      0.32      0.28      1000
#            weighted avg       0.38      0.40      0.35      1000
# [Parallel(n_jobs=16)]: Done 100 out of 100 | elapsed:    0.1s finished

# %%
from sklearn.metrics import accuracy_score, classification_report
import numpy as np
import pandas as pd

# ----------------------------------------------------------------------------
# STEP 6: Make Predictions and Evaluate Model
# ----------------------------------------------------------------------------
rf_pred_probs = rf_model.predict_proba(X_test_eval)  # Get probability distributions
rf_predictions = np.argmax(rf_pred_probs, axis=1)  # Get the most probable player (Top-1 Prediction)

# Remove any test labels that are -1 before inverse transformation
y_test_filtered = y_test_eval[y_test_eval != -1]  # Exclude unseen labels

# Convert numeric predictions back to player names (Ensure values exist in le.classes_)
y_pred_names = le.inverse_transform(rf_predictions[:len(y_test_filtered)])  # Match length of y_test_filtered
y_test_names = le.inverse_transform(y_test_filtered)  # Ensure only known labels are used

# **Compute Top-3 Predictions**
top_3_preds = np.argsort(rf_pred_probs, axis=1)[:, -3:]  # Indices of top 3 predictions
top_3_pred_names = np.array([le.inverse_transform(row) for row in top_3_preds[:len(y_test_filtered)]])

# **Check if Actual Player is in Top-3 Predictions**
top_3_correct = np.array([y_test_names[i] in top_3_pred_names[i] for i in range(len(y_test_names))])
top_3_accuracy = np.mean(top_3_correct)  # Compute Top-3 Accuracy

# **Compute Top-5 Predictions**
top_5_preds = np.argsort(rf_pred_probs, axis=1)[:, -5:]  # Indices of top 5 predictions
top_5_pred_names = np.array([le.inverse_transform(row) for row in top_5_preds[:len(y_test_filtered)]])

# **Check if Actual Player is in Top-5 Predictions**
top_5_correct = np.array([y_test_names[i] in top_5_pred_names[i] for i in range(len(y_test_names))])
top_5_accuracy = np.mean(top_5_correct)  # Compute Top-5 Accuracy

# **Compute Top-7 Predictions**
top_7_preds = np.argsort(rf_pred_probs, axis=1)[:, -7:]  # Indices of top 5 predictions
top_7_pred_names = np.array([le.inverse_transform(row) for row in top_7_preds[:len(y_test_filtered)]])

# **Check if Actual Player is in Top-7 Predictions**
top_7_correct = np.array([y_test_names[i] in top_7_pred_names[i] for i in range(len(y_test_names))])
top_7_accuracy = np.mean(top_7_correct)  # Compute Top-7 Accuracy

# **Compute Top-10 Predictions**
top_10_preds = np.argsort(rf_pred_probs, axis=1)[:, -10:]  # Indices of top 10 predictions
top_10_pred_names = np.array([le.inverse_transform(row) for row in top_10_preds[:len(y_test_filtered)]])

# **Check if Actual Player is in Top-10 Predictions**
top_10_correct = np.array([y_test_names[i] in top_10_pred_names[i] for i in range(len(y_test_names))])
top_10_accuracy = np.mean(top_10_correct)  # Compute Top-10 Accuracy

# Generate classification report
unique_labels = np.unique(y_test_filtered)  # Drop NaN values to avoid issues
target_names = [le.classes_[i] for i in unique_labels]

# **Store Predictions in DataFrame**
df_results = pd.DataFrame({
    'actual_player': y_test_names,
    'predicted_player': y_pred_names,
    'top_3_predictions': [list(row) for row in top_3_pred_names],
    'top_3_correct': top_3_correct,
    'top_5_predictions': [list(row) for row in top_5_pred_names],
    'top_5_correct': top_5_correct,
    'top_7_predictions': [list(row) for row in top_7_pred_names],
    'top_7_correct': top_7_correct,
    'top_10_predictions': [list(row) for row in top_10_pred_names],
    'top_10_correct': top_10_correct
})

# **Display Metrics**
print(f"🎯 Random Forest Top-1 Accuracy: {accuracy_score(y_test_filtered, rf_predictions[:len(y_test_filtered)]):.4f}")
print(f"🎯 Random Forest Top-3 Accuracy: {top_3_accuracy:.4f}")
print(f"🎯 Random Forest Top-5 Accuracy: {top_5_accuracy:.4f}")
print(f"🎯 Random Forest Top-7 Accuracy: {top_7_accuracy:.4f}")
print(f"🎯 Random Forest Top-10 Accuracy: {top_10_accuracy:.4f}")
print("\n📊 Classification Report:")
print(classification_report(y_test_filtered, rf_predictions[:len(y_test_filtered)], labels=unique_labels, target_names=target_names))

# **Show Sample Predictions**
print("\n🔍 Sample Predictions:")
print(df_results.head(30))  # Show first 15 rows of results
# Out:
# [Parallel(n_jobs=16)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=16)]: Done 100 out of 100 | elapsed:    0.1s finished
# 🎯 Random Forest Top-1 Accuracy: 0.3891
# 🎯 Random Forest Top-3 Accuracy: 0.6613
# 🎯 Random Forest Top-5 Accuracy: 0.7520
# 🎯 Random Forest Top-7 Accuracy: 0.7964
# 🎯 Random Forest Top-10 Accuracy: 0.8347
#
# 📊 Classification Report:
#                          precision    recall  f1-score   support
#
#              A.J. Price       0.00      0.00      0.00         1
#            Aaron Brooks       0.50      1.00      0.67         2
#                Acie Law       0.00      0.00      0.00         1
#           Al Harrington       0.00      0.00      0.00         2
#              Al Horford       0.38      1.00      0.55         3
#            Al Jefferson       0.50      1.00      0.67         4
#         Al-Farouq Aminu       0.50      1.00      0.67         1
#           Alan Anderson       0.50      1.00      0.67         1
#              Alec Burks       0.00      0.00      0.00         1
#            Alexey Shved       0.00      0.00      0.00         1
#           Alexis Ajinca       0.00      0.00      0.00         1
#            Allen Crabbe       0.00      0.00      0.00         2
#           Allen Iverson       0.50      0.50      0.50         2
#       Amar'e Stoudemire       0.38      1.00      0.55         3
#            Amir Johnson       0.33      0.25      0.29         4
#        Anderson Varejao       0.40      1.00      0.57         2
#          Andray Blatche       0.00      0.00      0.00         1
#          Andre Drummond       0.67      1.00      0.80         2
#          Andre Iguodala       0.33      1.00      0.50         2
#            Andre Miller       0.67      0.40      0.50         5
#         Andrea Bargnani       0.00      0.00      0.00         3
#        Andrei Kirilenko       0.43      0.60      0.50         5
#          Andres Nocioni       1.00      0.20      0.33         5
#            Andrew Bogut       0.25      0.50      0.33         2
#        Andrew Nicholson       1.00      0.33      0.50         3
#         Andris Biedrins       0.50      1.00      0.67         3
#          Antawn Jamison       1.00      0.67      0.80         3
#          Anthony Carter       0.00      0.00      0.00         1
#           Anthony Davis       0.00      0.00      0.00         1
#         Anthony Johnson       1.00      0.50      0.67         2
#          Anthony Morrow       1.00      0.50      0.67         2
#          Anthony Parker       0.50      0.25      0.33         4
#          Antoine Walker       1.00      0.50      0.67         2
#          Antoine Wright       0.00      0.00      0.00         2
#         Antonio McDyess       0.62      1.00      0.77         5
#             Aron Baynes       0.00      0.00      0.00         1
#           Arron Afflalo       0.33      0.17      0.22         6
#           Austin Rivers       0.00      0.00      0.00         1
#             Baron Davis       1.00      0.33      0.50         3
#              Ben Gordon       0.50      0.67      0.57         3
#             Ben Wallace       0.00      0.00      0.00         1
#              Beno Udrih       0.33      1.00      0.50         1
#           Blake Griffin       0.60      1.00      0.75         3
#        Bojan Bogdanovic       0.00      0.00      0.00         1
#           Tracy McGrady       1.00      0.50      0.67         2
#           Travis Diener       0.00      0.00      0.00         1
#           Travis Outlaw       1.00      1.00      1.00         2
#         Trenton Hassell       0.00      0.00      0.00         1
#            Trevor Ariza       0.25      1.00      0.40         1
#              Trey Burke       1.00      1.00      1.00         1
#        Tristan Thompson       0.17      0.25      0.20         4
#             Troy Murphy       1.00      1.00      1.00         3
#               Ty Lawson       0.43      0.75      0.55         4
#             Tyler Ennis       0.00      0.00      0.00         1
#        Tyler Hansbrough       1.00      1.00      1.00         2
#            Tyler Zeller       0.00      0.00      0.00         2
#            Tyreke Evans       0.40      1.00      0.57         2
#            Tyrus Thomas       0.00      0.00      0.00         1
#          Tyson Chandler       0.60      1.00      0.75         3
#           Udonis Haslem       0.40      0.67      0.50         3
#          Victor Oladipo       1.00      1.00      1.00         2
#            Vince Carter       0.50      0.67      0.57         3
#               Von Wafer       0.00      0.00      0.00         1
#         Wayne Ellington       1.00      0.33      0.50         3
#          Wesley Johnson       0.00      0.00      0.00         1
#         Wesley Matthews       0.50      1.00      0.67         1
#             Will Barton       0.00      0.00      0.00         1
#              Will Bynum       1.00      0.50      0.67         2
#            Willie Green       1.00      1.00      1.00         2
#         Wilson Chandler       0.45      0.83      0.59         6
#        Yakhouba Diawara       0.00      0.00      0.00         1
#           Zach Randolph       0.78      1.00      0.88         7
#           Zaza Pachulia       0.40      1.00      0.57         4
#      Zydrunas Ilgauskas       0.60      1.00      0.75         3
#
#               micro avg       0.41      0.39      0.40       992
#               macro avg       0.30      0.32      0.27       992
#            weighted avg       0.38      0.39      0.34       992
#
#
# 🔍 Sample Predictions:
#          actual_player  predicted_player  \
# 0          Troy Murphy       Troy Murphy
# 1          Chuck Hayes     Shane Battier
# 2          Brent Barry     Manu Ginobili
# 3          Craig Smith     Kevin Garnett
# 4       Stromile Swift          Rudy Gay
# 5         Charlie Bell      Michael Redd
# 6          Dwyane Wade       Dwyane Wade
# 7     Anderson Varejao  Anderson Varejao
# 8      Mickael Pietrus       Monta Ellis
# 9     Yakhouba Diawara         Ty Lawson
# 10    Damon Stoudamire       Mike Conley
# 11       Carlos Boozer    Deron Williams
# 12        Paul Millsap      Paul Millsap
# 13           Ime Udoka       Brandon Roy
# 14      Michael Doleac     Udonis Haslem
# 15       Dwight Howard     Dwight Howard
# 16      Antoine Walker       Dwyane Wade
# 17  Quentin Richardson   Wilson Chandler
# 18     Renaldo Balkman     Nate Robinson
# 19          J.R. Smith   Carmelo Anthony
# 20       Allen Iverson     Allen Iverson
# 21       Maurice Evans       Kobe Bryant
# 22     Stephon Marbury   Wilson Chandler
# 23         Matt Barnes       Monta Ellis
# 24     Martell Webster     Nicolas Batum
# 25        Chris Webber   Rasheed Wallace
# 26         Damon Jones  Anderson Varejao
# 27      Antawn Jamison    Antawn Jamison
# 28         Luther Head     Shane Battier
# 29     Antonio McDyess   Antonio McDyess
#
#                                       top_3_predictions  top_3_correct  \
# 0          [Roy Hibbert, Tyler Hansbrough, Troy Murphy]           True
# 1              [Luis Scola, Chuck Hayes, Shane Battier]           True
# 2             [Bruce Bowen, George Hill, Manu Ginobili]          False
# 3            [Al Jefferson, Craig Smith, Kevin Garnett]           True
# 4            [Tarence Kinsey, Stromile Swift, Rudy Gay]           True
# 5          [Charlie Bell, Ersan Ilyasova, Michael Redd]           True
# 6             [Dorell Wright, James Posey, Dwyane Wade]           True
# 7         [Daniel Gibson, Alonzo Gee, Anderson Varejao]           True
# 8           [Stephen Curry, Klay Thompson, Monta Ellis]          False
# 9           [Yakhouba Diawara, Nene Hilario, Ty Lawson]           True
# 10             [Marc Gasol, Hakim Warrick, Mike Conley]          False
# 11         [Mehmet Okur, Carlos Boozer, Deron Williams]           True
# 12           [Mehmet Okur, Ronnie Brewer, Paul Millsap]           True
# 13     [LaMarcus Aldridge, Damian Lillard, Brandon Roy]          False
# 14    [Michael Doleac, Shaquille O'Neal, Udonis Haslem]           True
# 15        [Jameer Nelson, Hedo Turkoglu, Dwight Howard]           True
# 16         [Dorell Wright, Antoine Walker, Dwyane Wade]           True
# 17   [Tyson Chandler, Stephon Marbury, Wilson Chandler]          False
# 18     [Jamal Crawford, Renaldo Balkman, Nate Robinson]           True
# 19          [J.R. Smith, Earl Boykins, Carmelo Anthony]           True
# 20      [Carmelo Anthony, Arron Afflalo, Allen Iverson]           True
# 21           [Jordan Farmar, Derek Fisher, Kobe Bryant]          False
# 22   [Tyson Chandler, Stephon Marbury, Wilson Chandler]           True
# 23          [Klay Thompson, Stephen Curry, Monta Ellis]          False
# 24  [Martell Webster, LaMarcus Aldridge, Nicolas Batum]           True
# 25    [Chris Webber, Richard Hamilton, Rasheed Wallace]           True
# 26        [Alonzo Gee, Daniel Gibson, Anderson Varejao]          False
# 27      [Brendan Haywood, Caron Butler, Antawn Jamison]           True
# 28            [Rafer Alston, Luis Scola, Shane Battier]          False
# 29   [Jason Maxiell, Chauncey Billups, Antonio McDyess]           True
#
#                                                                         top_5_predictions  \
# 0            [Mike Dunleavy, Stephen Jackson, Roy Hibbert, Tyler Hansbrough, Troy Murphy]
# 1                      [Kyle Lowry, Rafer Alston, Luis Scola, Chuck Hayes, Shane Battier]
# 2                     [Matt Bonner, Brent Barry, Bruce Bowen, George Hill, Manu Ginobili]
# 3                    [Al Horford, Corey Brewer, Al Jefferson, Craig Smith, Kevin Garnett]
# 4                  [Mike Miller, Zach Randolph, Tarence Kinsey, Stromile Swift, Rudy Gay]
# 5                 [Andrew Bogut, Mo Williams, Charlie Bell, Ersan Ilyasova, Michael Redd]
# 6                 [Mario Chalmers, LeBron James, Dorell Wright, James Posey, Dwyane Wade]
# 7                 [Drew Gooden, Ben Wallace, Daniel Gibson, Alonzo Gee, Anderson Varejao]
# 8               [Matt Barnes, Mickael Pietrus, Stephen Curry, Klay Thompson, Monta Ellis]
# 9              [Marcus Camby, Wilson Chandler, Yakhouba Diawara, Nene Hilario, Ty Lawson]
# 10               [Dahntay Jones, Greivis Vasquez, Marc Gasol, Hakim Warrick, Mike Conley]
# 11                [Paul Millsap, Kyle Korver, Mehmet Okur, Carlos Boozer, Deron Williams]
# 12                   [Ronnie Price, Trey Burke, Mehmet Okur, Ronnie Brewer, Paul Millsap]
# 13          [Nicolas Batum, Andre Miller, LaMarcus Aldridge, Damian Lillard, Brandon Roy]
# 14         [Mario Chalmers, James Posey, Michael Doleac, Shaquille O'Neal, Udonis Haslem]
# 15              [Darko Milicic, J.J. Redick, Jameer Nelson, Hedo Turkoglu, Dwight Howard]
# 16                [LeBron James, James Posey, Dorell Wright, Antoine Walker, Dwyane Wade]
# 17       [Zach Randolph, Toney Douglas, Tyson Chandler, Stephon Marbury, Wilson Chandler]
# 18   [Jared Jeffries, Quentin Richardson, Jamal Crawford, Renaldo Balkman, Nate Robinson]
# 19          [Chris Andersen, Chauncey Billups, J.R. Smith, Earl Boykins, Carmelo Anthony]
# 20           [Al Harrington, Andre Miller, Carmelo Anthony, Arron Afflalo, Allen Iverson]
# 21                    [Kwame Brown, Lamar Odom, Jordan Farmar, Derek Fisher, Kobe Bryant]
# 22        [Toney Douglas, Tim Hardaway, Tyson Chandler, Stephon Marbury, Wilson Chandler]
# 23              [Mickael Pietrus, Matt Barnes, Klay Thompson, Stephen Curry, Monta Ellis]
# 24  [Sergio Rodriguez, Rudy Fernandez, Martell Webster, LaMarcus Aldridge, Nicolas Batum]
# 25      [Tayshaun Prince, Jason Maxiell, Chris Webber, Richard Hamilton, Rasheed Wallace]
# 26               [LeBron James, Drew Gooden, Alonzo Gee, Daniel Gibson, Anderson Varejao]
# 27             [John Wall, Andray Blatche, Brendan Haywood, Caron Butler, Antawn Jamison]
# 28                     [Kyle Lowry, Luther Head, Rafer Alston, Luis Scola, Shane Battier]
# 29      [Allen Iverson, Carlos Delfino, Jason Maxiell, Chauncey Billups, Antonio McDyess]
#
#     top_5_correct  \
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
# 5            True
# 6            True
# 7            True
# 8            True
# 9            True
# 10          False
# 11           True
# 12           True
# 13          False
# 14           True
# 15           True
# 16           True
# 17          False
# 18           True
# 19           True
# 20           True
# 21          False
# 22           True
# 23           True
# 24           True
# 25           True
# 26          False
# 27           True
# 28           True
# 29           True
#
#                                                                                                      top_7_predictions  \
# 0          [Solomon Hill, Shawne Williams, Mike Dunleavy, Stephen Jackson, Roy Hibbert, Tyler Hansbrough, Troy Murphy]
# 1                        [James Harden, Luther Head, Kyle Lowry, Rafer Alston, Luis Scola, Chuck Hayes, Shane Battier]
# 2                      [Gary Neal, Fabricio Oberto, Matt Bonner, Brent Barry, Bruce Bowen, George Hill, Manu Ginobili]
# 3                     [Andre Iguodala, Kevin Love, Al Horford, Corey Brewer, Al Jefferson, Craig Smith, Kevin Garnett]
# 4                       [Mike Conley, Pau Gasol, Mike Miller, Zach Randolph, Tarence Kinsey, Stromile Swift, Rudy Gay]
# 5        [Charlie Villanueva, Brandon Jennings, Andrew Bogut, Mo Williams, Charlie Bell, Ersan Ilyasova, Michael Redd]
# 6                 [Gary Payton, Antoine Walker, Mario Chalmers, LeBron James, Dorell Wright, James Posey, Dwyane Wade]
# 15                      [Rashard Lewis, Courtney Lee, Carlos Arroyo, Glen Davis, Grant Hill, Darko Milicic, J.J. Redick, Jameer Nelson, Hedo Turkoglu, Dwight Howard]
# 16                       [Eddie Jones, Chris Quinn, Mario Chalmers, Gary Payton, Joel Anthony, LeBron James, James Posey, Dorell Wright, Antoine Walker, Dwyane Wade]
# 17  [Nate Robinson, Quentin Richardson, Tim Hardaway, Steve Francis, Renaldo Balkman, Zach Randolph, Toney Douglas, Tyson Chandler, Stephon Marbury, Wilson Chandler]
# 18      [Raymond Felton, Carmelo Anthony, Eddy Curry, Stephon Marbury, David Lee, Jared Jeffries, Quentin Richardson, Jamal Crawford, Renaldo Balkman, Nate Robinson]
# 19       [Danilo Gallinari, Andre Miller, Kenneth Faried, Anthony Carter, Arron Afflalo, Chris Andersen, Chauncey Billups, J.R. Smith, Earl Boykins, Carmelo Anthony]
# 20              [J.R. Smith, Ty Lawson, Danilo Gallinari, Andre Iguodala, Anthony Carter, Al Harrington, Andre Miller, Carmelo Anthony, Arron Afflalo, Allen Iverson]
# 21                          [Josh Powell, Metta World Peace, Andrew Bynum, Pau Gasol, Luke Walton, Kwame Brown, Lamar Odom, Jordan Farmar, Derek Fisher, Kobe Bryant]
# 22      [Jamal Crawford, Nate Robinson, Steve Francis, Zach Randolph, Renaldo Balkman, Toney Douglas, Tim Hardaway, Tyson Chandler, Stephon Marbury, Wilson Chandler]
# 23                  [Jarrett Jack, Mike Dunleavy, David Lee, Ronny Turiaf, Kelenna Azubuike, Mickael Pietrus, Matt Barnes, Klay Thompson, Stephen Curry, Monta Ellis]
# 24       [Jarrett Jack, Robin Lopez, Travis Outlaw, Joel Przybilla, Steve Blake, Sergio Rodriguez, Rudy Fernandez, Martell Webster, LaMarcus Aldridge, Nicolas Batum]
# 25    [Lindsey Hunter, Chauncey Billups, Jonas Jerebko, Rodney Stuckey, Greg Monroe, Tayshaun Prince, Jason Maxiell, Chris Webber, Richard Hamilton, Rasheed Wallace]
# 26                     [David Wesley, Antawn Jamison, Dion Waiters, Ben Wallace, Damon Jones, LeBron James, Drew Gooden, Alonzo Gee, Daniel Gibson, Anderson Varejao]
# 27           [JaVale McGee, Gilbert Arenas, Nick Young, DeShawn Stevenson, Antonio Daniels, John Wall, Andray Blatche, Brendan Haywood, Caron Butler, Antawn Jamison]
# 28                               [Josh Smith, Jeremy Lin, James Harden, Chuck Hayes, Tracy McGrady, Kyle Lowry, Luther Head, Rafer Alston, Luis Scola, Shane Battier]
# 29        [Richard Hamilton, Austin Daye, Amir Johnson, Tayshaun Prince, Ben Gordon, Allen Iverson, Carlos Delfino, Jason Maxiell, Chauncey Billups, Antonio McDyess]
#
#     top_10_correct
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# 5             True
# 6             True
# 7             True
# 8             True
# 9             True
# 10            True
# 11            True
# 12            True
# 13           False
# 14            True
# 15            True
# 16            True
# 17            True
# 18            True
# 19            True
# 20            True
# 21           False
# 22            True
# 23            True
# 24            True
# 25            True
# 26            True
# 27            True
# 28            True
# 29            True

# %%
df_results.to_csv("../data/results_final.csv", index=False)
